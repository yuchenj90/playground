# %%
pd.read_csv?
# Out:
# Signature:
# pd.read_csv(
#     filepath_or_buffer: 'FilePath | ReadCsvBuffer[bytes] | ReadCsvBuffer[str]',
#     *,
#     sep: 'str | None | lib.NoDefault' = <no_default>,
#     delimiter: 'str | None | lib.NoDefault' = None,
#     header: "int | Sequence[int] | None | Literal['infer']" = 'infer',
#     names: 'Sequence[Hashable] | None | lib.NoDefault' = <no_default>,
#     index_col: 'IndexLabel | Literal[False] | None' = None,
#     usecols=None,
#     squeeze: 'bool | None' = None,
#     prefix: 'str | lib.NoDefault' = <no_default>,
#     mangle_dupe_cols: 'bool' = True,
#     dtype: 'DtypeArg | None' = None,
#     engine: 'CSVEngine | None' = None,
#     converters=None,
#     true_values=None,
#     false_values=None,
#     skipinitialspace: 'bool' = False,
#     skiprows=None,
#     skipfooter: 'int' = 0,
#     nrows: 'int | None' = None,
#     na_values=None,
#     keep_default_na: 'bool' = True,
#     na_filter: 'bool' = True,
#     verbose: 'bool' = False,
# ...

# %%
import pandas as pd
df_train = pd.read_csv('../../../data/loaded-reviews.csv')

# %%
df_train['flagged'].value_counts()
# Out:
# N    20752
# Y     6206
# Name: flagged, dtype: int64

# %%
df_train.location.value_counts()
# Out:
# Chicago, IL             17821
# San Francisco, CA         409
# Los Angeles, CA           270
# New York, NY              266
# Evanston, IL              244
#                         ...
# Clinton Township, MI        1
# Cortland, IL                1
# Cassopolis, MI              1
# Absecon, NJ                 1
# Fox Lake, IL                1
# Name: location, Length: 1483, dtype: int64

# %%
df_train.loc[10,'reviewContent']
# Out:
# "1st I will say I'm not a foodie but I enjoy dining w foodies. The service was impeccable. The presentation of food was truly marvelous. I am allergic to all seafood & fish. My friend is a vegetarian. They prepared special menus for both. Now to the food. Some courses were delicious others were ok. Everything was too small. Even if u liked it was gone in 3 bites. Even though there were so many courses we left hungry & went out afterwards. 2 of my friends are foodies & have been to very elite restaurants. Also, I do not have a need to be stuffed after eating out, but I do want to be satisfied. I was neither which was disappointing considering the price tag. The atmosphere was quiet. Was good girls night out. Dessert was huge disappointment. Dippin dots spread all over table. Price in my opinion not worth it. The biggest irritation was the champaign @ beginning of meal was brought out though we did not request it. I assumed it was complimentary. However it turned out to be $100 each. I
# ...

# %%
import pandas
import json

# Open and read the JSON file
l = []
i = 0
with open('../../../data/yelp_academic_dataset_review.json', 'r') as f:
    for line in f:
        l.append(json.loads(line))
        i+=1
        if i>100:
            break

# %%
l
# Out:
# [{'review_id': 'KU_O5udG6zpxOg-VcAEodg',
#   'user_id': 'mh_-eMZ6K5RLWhZyISBhwA',
#   'business_id': 'XQfwVwDr-v0ZS3_CbbE5Xw',
#   'stars': 3.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "If you decide to eat here, just be aware it is going to take about 2 hours from beginning to end. We have tried it multiple times, because I want to like it! I have been to it's other locations in NJ and never had a bad experience. \n\nThe food is good, but it takes a very long time to come out. The waitstaff is very young, but usually pleasant. We have just had too many experiences where we spent way too long waiting. We usually opt for another diner or restaurant on the weekends, in order to be done quicker.",
#   'date': '2018-07-07 22:09:11'},
#  {'review_id': 'BiTunyQ73aT9WBnpR9DZGw',
#   'user_id': 'OyoGAe7OKpv6SyGZT5g77Q',
#   'business_id': '7ATYjTIgM3jUlt4UM3IypQ',
#   'stars': 5.0,
#   'useful': 1,
#   'funny': 0,
#   'cool': 1,
# ...

# %%
import json

data = []
with open('file') as f:
    for line in f:
        data.append(json.loads(line))

# %%
data

# %%
# Out:
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?keyword=restaurant&location=37.4539646%2C-122.1669212&radius=1000&type=restaurant&key=AIzaSyBivqxSv7wjeFey1PQAo2hC8AmlpsJi15w

# %%
import json

# %%
[d['name'] for d in data['results']]
# Out:
# ["Guapa's Mexican Grill",
#  'Il Fornaio',
#  'Local Union 271',
#  'Sushirrito',
#  'Nola',
#  'Menlo Tavern',
#  'New York Pizza Palo Alto',
#  'Taste',
#  "Sancho's Taqueria",
#  'YAYOI Palo Alto',
#  "Mardini's Deli Cafe",
#  "Jeffrey's Hamburgers",
#  'Cafe 220',
#  'MP Mongolian BBQ',
#  'Chipotle Mexican Grill',
#  'Rooh',
#  'Pizza My Heart',
#  'Buca di Beppo Italian Restaurant',
#  'Pho Banh Mi',
#  'Crepevine Restaurants']

# %%
place_id = 'ChIJKQDyuVGlj4ARv_rHjJdjDAw'
params = f"place_id={place_id}&key={API_KEY}"
r = requests.get(f"https://maps.googleapis.com/maps/api/place/details/json?{params}")

# %%
json.loads(r.content)['result']['reviews']
# Out:
# [{'author_name': 'Tammy A.',
#   'author_url': 'https://www.google.com/maps/contrib/103559141303838228074/reviews',
#   'language': 'en',
#   'original_language': 'en',
#   'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjXJdDE73zMWRijO557Qe2EcsRukxrTh_TBbx0K8ASJz1elxbUom=s128-c0x00000000-cc-rp-mo',
#   'rating': 5,
#   'relative_time_description': '5 months ago',
#   'text': "Great Mexican place in the former Rubio's. We noticed it was open the last time we shopped at the Safeway in this strip mall but we had already eaten, so I made sure to save dinner for this trip. I had the taco trio with pollo verde, barbacoa and al pastor, all with fajita veggies and pinto beans. Spouse had nachos with pollo asado. Fantastic fresh flavors and quality. Very bright interior design. Guapa's will be a regular stop. I hope they do well and don't get bought out by a private equity firm.",
#   'time': 1713148959,
#   'translated': False},
#  {'author_name': 'Marc Masnik',
# ...

# %%
for d in data['results']:
# Out:
# [{'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 37.4496803, 'lng': -122.1784631},
#    'viewport': {'northeast': {'lat': 37.45110592989272,
#      'lng': -122.1770447201073},
#     'southwest': {'lat': 37.44840627010728, 'lng': -122.1797443798927}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': "Guapa's Mexican Grill",
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 4284,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100336765886700315252">Benjamin Wright</a>'],
#     'photo_reference': 'AdCG2DNRbUfU7hHm1VQhjZ9DOE4nEmpF5rMcaldDCWoq0C0LPVvk3yLB8RZC4OzRjlVTI8mhG_FwU2geN6kLU4sEYhggaz5rgOjKB2-XZS1vo2K04SrUprhDrbRVkVbIbtPjHKEi9DDjVJg-1Fz3ku_qTDFvh--OJWkEopykOZp71myopwT9',
#     'width': 5712}],
# ...

# %%
for d in data:

# %%
len(data)
# Out:
# 4

# %%
import requests
output = "json"
r = requests.get(f"https://maps.googleapis.com/maps/api/place/details/{output}?{parameters}")

# %%
r.status_code
# Out:
# 401

# %%
r
# Out:
# <Response [401]>

# %%
import requests
from bs4 import BeautifulSoup

URL = "https://www.tripadvisor.com/Airline_Review-d8729020-Reviews-American-Airlines.html#REVIEWSa"
r = requests.get(URL)

soup = BeautifulSoup(r.content, 'html5lib') # If this line causes an error, run 'pip install html5lib' or install html5lib
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    tripadvisor.com
#   </title>
#   <style>
#    #cmsg{animation: A 1.5s;}@keyframes A{0%{opacity:0;}99%{opacity:0;}100%{opacity:1;}}
#   </style>
#  </head>
#  <body style="margin:0">
#   <p id="cmsg">
#    Please enable JS and disable any ad blocker
#   </p>
#   <script data-cfasync="false">
#    var dd={'rt':'c','cid':'AHrlqAAAAAMA95qaSXgsHbsAhsMABQ==','hsh':'2F05D671381DB06BEE4CC52C7A6FD3','t':'bv','s':46694,'e':'bfacc64e69084f10b5a4198da3c530c981647471d174acfafde3f48062791561','host':'geo.captcha-delivery.com'}
#   </script>
#   <script data-cfasync="false" src="https://ct.captcha-delivery.com/c.js">
#   </script>
#  </body>
# </html>

# %%
r.content.
# Out:
# b'<html><head><title>tripadvisor.com</title><style>#cmsg{animation: A 1.5s;}@keyframes A{0%{opacity:0;}99%{opacity:0;}100%{opacity:1;}}</style></head><body style="margin:0"><p id="cmsg">Please enable JS and disable any ad blocker</p><script data-cfasync="false">var dd={\'rt\':\'c\',\'cid\':\'AHrlqAAAAAMA95qaSXgsHbsAhsMABQ==\',\'hsh\':\'2F05D671381DB06BEE4CC52C7A6FD3\',\'t\':\'bv\',\'s\':46694,\'e\':\'bfacc64e69084f10b5a4198da3c530c981647471d174acfafde3f48062791561\',\'host\':\'geo.captcha-delivery.com\'}</script><script data-cfasync="false" src="https://ct.captcha-delivery.com/c.js"></script></body></html>'

# %%
table = soup.find('div', attrs = {'id':'all_quotes'})

# %%
table

# %%
https://www.tripadvisor.com/Airline_Review-d8729020-Reviews-or10-American-Airlines.html#REVIEWS
