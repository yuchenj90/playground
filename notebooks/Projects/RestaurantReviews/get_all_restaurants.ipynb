# %%
import json, requests

# %%
import os
from dotenv import load_dotenv
load_dotenv()
API_KEY = os.getenv("GOOGLE_PLACE_API_KEY")

# %%
API_KEY
# Out:
# 'AIzaSyBVdTJUE3XEQ1qNNuaAtXCTcUPV2NClAas'

# %% [markdown]
# # Using asyncio

# %%
def get_nearby_restaurants(lat, lng, rad="10000", stype="restaurant"):
    params = f"location={lat}%2C{lng}&radius={rad}&type={stype}&rankby=prominence&key={API_KEY}"
    URL_NearbySearch = f"https://maps.googleapis.com/maps/api/place/nearbysearch/json?{params}"
    r = requests.get(URL_NearbySearch)
    data = json.loads(r.content)
    return data['results']

# %%
lat = "34.0200393"
lng = "-118.7413648"
d = get_nearby_restaurants(lat, lng)

# %%
def get_restaurants(lat, lng, limit = 1000):
    queue = [{'name': '', 'place_id': '', 'lat': lat, 'lng': lng}]
    visited = {}
    p = 0
    while p < len(queue):
        x = queue[p]
        res = get_nearby_restaurants(x['lat'], x['lng'])
        for d in res:
            if d['place_id'] not in visited:
                visited[d['place_id']] = True
                queue.append({'name': d['name'], 'place_id': d['place_id'], 
                              'lat': d['geometry']['location']['lat'], 'lng': d['geometry']['location']['lng']})
        p += 1
        if len(queue) > limit:
            break
    return queue

# %%
import time
start_time = time.time()
q = get_restaurants(lat,lng,100)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 6.901461124420166 seconds ---

# %%
async def fetch_data(url):
    async with aiohttp.ClientSession() as session:
        async with session.get(url) as response:
            return await response.json()

async def get_batch_restaurants(data, rad="10000"):
    urls = []
    for d in data:
        params = f"location={d['lat']}%2C{d['lng']}&radius={rad}&type=restaurant&rankby=prominence&key={API_KEY}"
        urls.append(f"https://maps.googleapis.com/maps/api/place/nearbysearch/json?{params}")
    tasks = [fetch_data(url) for url in urls]
    res = []
    for x in await asyncio.gather(*tasks):
        res.extend(x['results'])
    return res
    
async def get_restaurants_parallel(lat, lng, limit = 1000, max_worker = 50):
    queue = [{'name': '', 'place_id': '', 'lat': lat, 'lng': lng}]
    visited = {}
    p = 0
    while p < len(queue):
        p_next = min([len(queue), p+max_worker])
        res = await get_batch_restaurants(queue[p:p_next])
        for x in res:
            if x['place_id'] not in visited:
                queue.append({'name': x['name'], 'place_id': x['place_id'], 
                              'lat': x['geometry']['location']['lat'], 'lng': x['geometry']['location']['lng']})
                visited[x['place_id']] = True
        if len(queue) > limit:
            break
        p = p_next
    return queue

# %%
import time
start_time = time.time()
data = await get_restaurants_parallel(lat,lng,100,10)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 1.4145760536193848 seconds ---

# %%
def get_reviews(d, place_id):
    res = []
    for reviews_sort in ['most_relevant', 'newest']:
        params = f"place_id={place_id}&reviews_sort={reviews_sort}&key={API_KEY}"
        r = requests.get(f"https://maps.googleapis.com/maps/api/place/details/json?{params}")
        res.extend(json.loads(r.content)['result']['reviews'])
    return d, res

# %%
def get_all_reviews(data, max_worker=50):
    def add_res(x):
        x[0]['reviews'] = x[1]
        
    pool = Pool(max_worker)
    res = []
    for d in data:
        pool.apply_async(get_reviews, args=(d, d['place_id']), callback=add_res)
    pool.close()
    pool.join()
    return data

# %%
import time
start_time = time.time()
restaurants_info = get_all_reviews(data[1:])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 7.4808220863342285 seconds ---

# %%
import json

with open("restaurants_info.json", 'w') as f:
    json.dump(restaurants_info, f, indent=2)

# %%
with open("restaurants_info.json", 'r') as f:
    x = json.load(f)

print(x)
# Out:
# [{'name': "Geoffrey's", 'place_id': 'ChIJHRDtTtIY6IAR1xN4Fw2fiGA', 'lat': 34.0253497, 'lng': -118.7698216}, {'name': 'Paradise Cove Beach Café', 'place_id': 'ChIJwbruq90Y6IARYuzvcpV-dYc', 'lat': 34.0202609, 'lng': -118.7872024}, {'name': 'Nobu Malibu', 'place_id': 'ChIJewC2XzIe6IARgQhofffh6fE', 'lat': 34.0390391, 'lng': -118.6696477}, {'name': 'Saddle Peak Lodge', 'place_id': 'ChIJIWi-LR4g6IARZNRM1sPXDGs', 'lat': 34.0782093, 'lng': -118.6931594}, {'name': 'Malibu Seafood Fresh Fish Market & Patio Cafe', 'place_id': 'ChIJC0xiTBof6IAR6ZbMPPS9weE', 'lat': 34.0338129, 'lng': -118.7350788}, {'name': "Duke's Malibu", 'place_id': 'ChIJG0Rdz-WgwoARkFKjcvcFARU', 'lat': 34.0364534, 'lng': -118.6358631}, {'name': 'Taverna Tony', 'place_id': 'ChIJE5TqjTIe6IAREtbysD5fqXE', 'lat': 34.0365955, 'lng': -118.6859276}, {'name': 'Subway', 'place_id': 'ChIJDzEfbjQe6IARsaKr2kOTpw0', 'lat': 34.03413159999999, 'lng': -118.6913849}, {'name': 'Ollo', 'place_id': 'ChIJr6hDqkwe6IARSTn4xwtNsAg', 'lat': 34.034147, 'lng': -118.693057}, {'name': 'SunLife Organics', 'place_id': 'ChIJKxOkjfYY6IAR-a-R5tNc5vU', 'lat': 34.0213559, 'lng': -118.809599}, {'name': 'Gravina Malibu', 'place_id': 'ChIJD2FCLvAY6IARoYOIqR6HN1E', 'lat': 34.0218198, 'lng': -118.8023202}, {'name': 'Malibu Farm Pier Cafe', 'place_id': 'ChIJTZbPtyse6IARnWiKAUms3LA', 'lat': 34.0356151, 'lng': -118.6756299}, {'name': 'Marmalade Cafe', 'place_id': 'ChIJDceIcDIe6IARpwSMNeVNvGY', 'lat': 34.03527070000001, 'lng': -118.6842264}, {'name': 'Starbucks', 'place_id': 'ChIJBxVwZQ4Y6IARYwRGcXEj714', 'lat': 34.03119220000001, 'lng': -118.8431336}, {'name': 'Tra di Noi', 'place_id': 'ChIJewC2XzIe6IARXI_lkK31E4E', 'lat': 34.0357975, 'lng': -118.6863831}, {'name': 'Starbucks', 'place_id': 'ChIJNafc-DQe6IAR1G0PxUYio6Y', 'lat': 34.0339747, 'lng': -118.693388}, {'name': "Lily's Malibu", 'place_id': 'ChIJX1Gc9fYY6IAR4rR1xuHYExk', 'lat': 34.0212829, 'lng': -118.8099614}, {'name': 'Jack in the Box', 'place_id': 'ChIJh0y6vSse6IARlvWdO3BLd2g', 'lat': 34.0373933, 'lng': -118.6775029}, {'name': 'Cafe Habana', 'place_id': 'ChIJTaJLbTIe6IAR3geAnwz1fd4', 'lat': 34.0345715, 'lng': -118.6856283}, {'name': 'Sunlife Organics', 'place_id': 'ChIJG_SEYDIe6IARHfeyKZFiHi0', 'lat': 34.035764, 'lng': -118.685696}, {'name': 'The Malibu Cafe', 'place_id': 'ChIJibxzhAYj6IART8OKIN6fGd4', 'lat': 34.0916894, 'lng': -118.8172405}, {'name': "D'amores Pizza", 'place_id': 'ChIJpVw0jPYY6IARd7kbDBcQrV8', 'lat': 34.0214039, 'lng': -118.8096214}, {'name': 'Calamigos Ranch', 'place_id': 'ChIJk5FzygYj6IARXHa8eG3QqsQ', 'lat': 34.092137, 'lng': -118.817412}, {'name': 'Spruzzo Restaurant & Bar', 'place_id': 'ChIJ0TeJJ1oY6IARNuXExqzvcvw', 'lat': 34.0168215, 'lng': -118.8190625}, {'name': "Kristy's Malibu", 'place_id': 'ChIJqaEvtFkY6IARPXj6hI7dzRI', 'lat': 34.03163519999999, 'lng': -118.8427484}, {'name': '86 All Day', 'place_id': 'ChIJI-KvDvcZ6IARoWZKY6HXcAc', 'lat': 34.0218037, 'lng': -118.8022642}, {'name': 'The Sunset Restaurant', 'place_id': 'ChIJoUWY828Z6IAREnjpkLUDyOk', 'lat': 34.0111749, 'lng': -118.8166924}, {'name': 'Zuma Cafe', 'place_id': 'ChIJx8-tU0IY6IARZ7cU7LutfFk', 'lat': 34.0207014, 'lng': -118.8288971}, {'name': 'Sabor A Malibu food Truck', 'place_id': 'ChIJTeR82WMj6IAR6pEIQpUSX-Y', 'lat': 34.03548809999999, 'lng': -118.8523864}, {'name': 'The Malibu Market', 'place_id': 'ChIJdRmv42sj6IARHQxWBLaN4Ug', 'lat': 34.0959926, 'lng': -118.8143877}, {'name': 'HAWC café and dining space', 'place_id': 'ChIJ7VzqOoQf6IARlZBenLEHqGc', 'lat': 34.0402405, 'lng': -118.7080341}, {'name': 'Moonshadows Malibu', 'place_id': 'ChIJLbXg4hihwoARwE802F81zfg', 'lat': 34.0375286, 'lng': -118.6186723}, {'name': 'Inn of the Seventh Ray', 'place_id': 'ChIJE5ZxtcKhwoARUsp1_h9PLOc', 'lat': 34.0902767, 'lng': -118.6047108}, {'name': 'Reel Inn Malibu', 'place_id': 'ChIJnUPzTV-hwoARvBHRv-cspr4', 'lat': 34.0398304, 'lng': -118.5816902}, {'name': 'Cholada Thai Beach Cuisine', 'place_id': 'ChIJ7fk7yl6hwoARRKPvth0l5mU', 'lat': 34.0391099, 'lng': -118.5840699}, {'name': "Mastr ...

# %% [markdown]
# # using asyncio

# %%
import aiohttp, asyncio

async def fetch_data(url):
    async with aiohttp.ClientSession() as session:
        async with session.get(url) as response:
            return await response.json()

async def get_all_reviews(data):
    urls = []
    for d in data:
        for reviews_sort in ['most_relevant', 'newest']:
            params = f"place_id={d['place_id']}&reviews_sort={reviews_sort}&key={API_KEY}"
            urls.append(f"https://maps.googleapis.com/maps/api/place/details/json?{params}")
    print(len(urls))
    tasks = [fetch_data(url) for url in urls]
    return await asyncio.gather(*tasks)
# Run the main function using 'asyncio.run()' if the script is executed

start_time = time.time()
#res = asyncio.run(get_all_reviews(data[1:]))
res = await get_all_reviews(data[1:])
print(f"Finished in {(time.time() - start_time)} seconds.")
# Out:
# 208
# Finished in 5.611766815185547 seconds.

# %%
place_dict = {}
for d in data[1:]:
    place_dict[d['place_id']] = d.copy()

# %%
for x in res:
    if 'reviews' in x['result']:
        if 'reviews' not in place_dict[x['result']['place_id']]:
            place_dict[x['result']['place_id']]['reviews'] = x['result']['reviews']
        else:
            place_dict[x['result']['place_id']]['reviews'].extend(x['result']['reviews'])

# %%
restaurant_info = list(place_dict.values())

# %%
restaurant_info
# Out:
# [{'name': "Geoffrey's",
#   'place_id': 'ChIJHRDtTtIY6IAR1xN4Fw2fiGA',
#   'lat': 34.0253497,
#   'lng': -118.7698216,
#   'reviews': [{'author_name': 'Peter Xaymountry',
#     'author_url': 'https://www.google.com/maps/contrib/107152190076731796260/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjW4-iw-e0tHl9zEINryHZo0RHkxSU2aUq1A5Ys5v7J6GgxmO6ZN=s128-c0x00000000-cc-rp-mo-ba7',
#     'rating': 4,
#     'relative_time_description': '4 weeks ago',
#     'text': "You come here for the view of the beach which is the main attraction especially if you get a good seat. I decided to take my wife here for her birthday so I made reservations ahead of time off OpenTable and told them we were celebrating a birthday so I wanted a table with good view of the water. We arrived early and use their valet parking because it's easier than finding street parking. The valet cost is already added to your bill so you don't have to worry about cash except for tip. We arrived early so we took advantage on walking down to the beach first. We checked in like 20 minutes before our reservation time but they were still able to seat us with a great table with good view of the water. Our waiter was Marvin and we thought he was great with us beside not telling me that the soda is not free refill. That was my only complaint with him but I didn't want to dispute so I just paid it but give less in the tip. My wife got the Pan Seared Chilean Sea Bass for her entree and a Georgia Peach martini for her drink. I got their Herb Crusted Salmon and ask for french fries for my sides. My wife loved her peach martini and of course her Sea Bass. I thought the Salmon was a bit dry and didn't have much favor but Marvin came around asking if I wanted crushed black pepper so I asked for that on the Salmon and fries. It helped a little but not that much to me. We finish off the night with a ice cream dessert where Marvin sang Happy Birthday to my wife. I would recommend coming here and making reservations if you want to experience a good view and some good food but just know that the soda does not have free refills.",
#     'time': 1725852601,
#     'translated': False},
#    {'author_name': 'Carman Carter',
#     'author_url': 'https://www.google.com/maps/contrib/101520279057737812167/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a/ACg8ocIKKaN7Ul4FlHA_qDnQcSiu3zwUyig_utY7Z6wwzAx7LOPN_g=s128-c0x00000000-cc-rp-mo-ba5',
#     'rating': 5,
#     'relative_time_description': 'a month ago',
#     'text': 'Geoffrey’s never disappoints! Been going here since 2001 and this place has not changed much.  Last time here was about 10 years ago.  Still same great service, food, and atmosphere!  Keep in mind if you choose to park on your own, good luck!  Highly recommend either car service or valet. The valet crew is so awesome and as always takes care of everyone with a smile! They were great with our driver. Super polite and accommodating when he dropped us off and picked us up.\nWe love to sit at the bar.  If you do this make sure you sit on the far side so you can see the ocean.  Our bartender was great!  Lots of personality and really enjoyed our time there.\nThe food as always was excellent! We went on a Sunday.  Sat and Sunday they have a great brunch menu.',
#     'time': 1725282499,
#     'translated': False},
#    {'author_name': 'Liz',
#     'author_url': 'https://www.google.com/maps/contrib/116886163617925008970/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjWZnS6QCoPLAi5H79CbNHBMAV0GrOm9UB5RNwt_TKpI54Ldm2pejw=s128-c0x00000000-cc-rp-mo-ba5',
#     'rating': 5,
#     'relative_time_description': 'in the last week',
#     'text': 'First time at this lovely restaurant.  Views and ambience are amazing, they only have valet parking which was $12 not including tip. The service was impeccable, they also did not rush the food service it was at a nice pace. Lovely presentation and food was delicious,  would not hesitate to go back. We were celebrating birthdays.',
#     'time': 1727806644,
#     'translated': False},
#    {'author_name': 'Jennifer Villasenor',
#     'author_url': 'https://www.google.com/maps/contrib/113372860495121882697/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjXxBi2C7_XnjfulHXrIAt7jvpfgGg8XYxJgucH70R6vKX4nUGlDJg=s128-c0x00000000-cc-rp-mo',
#     'rating': 4,
#     'relative_time_description': '3 weeks ago',
#     'text': 'Lovely view, ambiance, and service. I didn’t give it 5 stars because it was good but not amazing. I think the location is the biggest take away. Definitely pricey but not surprising. The waiters were really cool. Parking situation can def get crazy during peak hours . Seems very family oriented which is nice.',
#     'time': 1726352784,
#     'translated': False},
#    {'author_name': 'Shant Khach',
#     'author_url': 'https://www.google.com/maps/contrib/109352422604154094065/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjWm6TJxGt0joahs8kCc6OXUwy3J4tj4XGHfrZtpML1JX1iRXBo=s128-c0x00000000-cc-rp-mo-ba4',
#     'rating': 5,
#     'relative_time_description': 'a month ago',
#     'text': 'Great place with a nice view of the ocean.  They have valet parking and access to the ocean by walking the stairs down. Service is great and good was good too. We enjoyed our time there with our family and kids got happy by playing on the beach after our meal.',
#     'time': 1725297497,
#     'translated': False},
#    {'author_name': 'Mary Grikas',
#     'author_url': 'https://www.google.com/maps/contrib/108428563057077701753/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjU-4-_YMA7f2kcqxst907-2ST6pic3eVI0SAV2F6c7qaRTQbhMq=s128-c0x00000000-cc-rp-mo-ba3',
#     'rating': 5,
#     'relative_time_description': 'in the last week',
#     'text': 'Such a beautiful venue, attentive service and good food. The spicy fried oysters were unique and delicious. For dinner I had the scallops, really yummy and good sized!',
#     'time': 1728151848,
#     'translated': False},
#    {'author_name': 'Matt Rosner',
#     'author_url': 'https://www.google.com/maps/contrib/107478219060452706879/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjWFNuHHE3T4z5VU43AOk155CW7mX9f3pceK8gBydPZ738nzra6kHQ=s128-c0x00000000-cc-rp-mo-ba3',
#     'rating': 3,
#     'relative_time_description': 'in the last week',
#     'text': 'Fillet was burnt and flavorless. Tasted like steak from Sizzler.  Lobster was tough, chewy, and under lukewarm. Staff and atmosphere was great! Other than that, super overrated and overpriced for the quality of food.',
#     'time': 1727890317,
#     'translated': False},
#    {'author_name': 'Logan Frasier',
#     'author_url': 'https://www.google.com/maps/contrib/105309226970113790162/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjX-o_IagfrVxYRFkIzfEG33j9ubzErQeftA7iH3NcDjKMKd8IE=s128-c0x00000000-cc-rp-mo',
#     'rating': 5,
#     'relative_time_description': 'in the last week',
#     'text': "We had an amazing time at Geoffrey's on our 5th anniversary! The service is fantastic, great ambiance, wonderful food, with an amazing view of the Malibu coastline... just forget about getting out cheap; almost $400 for two people with three drinks each, and splitting a desert. That said, it's a really special place for a really special occasion, and we will be back... just not every week!",
#     'time': 1727815785,
#     'translated': False},
#    {'author_name': 'Liz',
#     'author_url': 'https://www.google.com/maps/contrib/116886163617925008970/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjWZnS6QCoPLAi5H79CbNHBMAV0GrOm9UB5RNwt_TKpI54Ldm2pejw=s128-c0x00000000-cc-rp-mo-ba5',
#     'rating': 5,
#     'relative_time_description': 'in the last week',
#     'text': 'First time at this lovely restaurant.  Views and ambience are amazing, they only have valet parking which was $12 not including tip. The service was impeccable, they also did not rush the food service it was at a nice pace. Lovely presentation and food was delicious,  would not hesitate to go back. We were celebrating birthdays.',
#     'time': 1727806644,
#     'translated': False},
#    {'author_name': 'Kris S',
#     'author_url': 'https://www.google.com/maps/contrib/101042286789059211171/reviews',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjVH5nmmT33jMOxj7wzt_84eK2pH-Mw6TCWgM9IrX2DIF4niPHc=s128-c0x00000000-cc-rp-mo',
#     'rating': 5,
#     'relative_time_description': 'in the last week',
#     'text': '',
#     'time': 1727766050,
#     'translated': False}]},
#  {'name': 'Paradise Cove Beach Café',
#   'place_id': 'ChIJwbruq90Y6IARYuzvcpV-dYc',
#   'lat': 34.0202609,
#   'lng': -118.7872024,
#   'reviews': [{'author_name': 'Ali Mohammadi',
#     'author_url': 'https://www.google.com/maps/contrib/112906064637794431581/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjU4qBTbpOt0btR9YaDTNepQq-6TI_d3ylDF41P7wVHGK_UtIxnb=s128-c0x00000000-cc-rp-mo-ba4',
#     'rating': 4,
#     'relative_time_description': '2 weeks ago',
#     'text': 'Spent an awesome Sunday afternoon at Paradise Cove Beach Café, and I can’t wait to go back! I started with a Mango Mojito that was so refreshing—perfect for a sunny day. For appetizers, we had the chips and guacamole, and the portion was huge, definitely enough for sharing. The fish and chips were on point, with crispy fries that were delicious. The chicken tacos were also packed with flavor.\n\nSome of the drinks came in actual pineapples and watermelons, which was a fun tropical touch! The view of the ocean was incredible and made for some perfect photo ops. Just a heads up, though: it can get a little chilly when the sun goes down depending on the time of the year, so bring a light jacket if you plan to stay into the evening.\n\nOverall, it’s the perfect spot to relax, enjoy great food and drinks, and take in the Malibu vibe. The ocean view is unbeatable, especially for photo ops. The only downside was that the staff seemed a bit overworked and tired, and I didn’t see many smiles, which might have been because it was the end of the weekend. Hopefully, that’s not always the case. Despite that, I’ll definitely be coming back!',
#     'time': 1726515605,
#     'translated': False},
#    {'author_name': 'Angel Lucero',
#     'author_url': 'https://www.google.com/maps/contrib/108318600936734641227/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjWEveHhwPz_X4SsL688x-FP8c7Q0DIr471beW_V0qyusIcvirgu=s128-c0x00000000-cc-rp-mo',
#     'rating': 4,
#     'relative_time_description': 'in the last week',
#     'text': 'Would highly recommend for those out of town.\nMade this reservation two weeks ahead, and loved the atmosphere. Private beach, outdoor seating and great place to have brunch with friends. The food was adequate and quite expensive. But would go again and is totally worth the drive from LA.',
#     'time': 1727722727,
#     'translated': False},
#    {'author_name': 'Jacqueline Caballero',
#     'author_url': 'https://www.google.com/maps/contrib/104052839466136443007/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a/ACg8ocKr2RNpYMETs0PhUFtbyXRUKvKvQuqsGH4XeOnHbVw_WNeQ7Q=s128-c0x00000000-cc-rp-mo',
#     'rating': 5,
#     'relative_time_description': '3 months ago',
#     'text': 'My husband and I came to this location to celebrate our anniversary and it was amazing! The food tasted spectacular, the drinks were good, and the ambiance was just so relaxing. I got the clam chowder in a bread bowl and it was bomb! They even bring the pot with extra chowder for you. My husband got the fish and chips and the fries were the best! They have indoor and outdoor seating, we went end of May so it wasn’t too busy so we were able to request outdoor seating and get seated right away. Overall great experience and we are definitely planning to come back again. Thank you for making our wedding anniversary one to remember 🥰',
#     'time': 1719690570,
#     'translated': False},
#    {'author_name': 'Andrew F',
#     'author_url': 'https://www.google.com/maps/contrib/108965770273304458767/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a/ACg8ocLSMuh8zPG7xTs6dLrNgsStUD0VpMLk38zaw_k1eDjoOaK-dg=s128-c0x00000000-cc-rp-mo-ba3',
#     'rating': 1,
#     'relative_time_description': 'a week ago',
#     'text': "Honestly, the food was underwhelming. No prices on the cocktails that range from $18-25 , I wonder why!  But the worst of it was 4 kids under 5 making a noise playing in the sand throwing it around, another table with a crying kid and a couple in front of us playing their own music as well as the restaurants music playing. When my daughter asked the couple very politely to turn their music off they wouldn’t. We told the waiter and he asked if he must ask everyone in the restaurant to turn their music off 😳, I have never! Where has restaurant etiquette gone to?! The service? Let's just say it left much to be desired. We got one waiter who was awful and then half way through another who was okay.  The view is nice, but that’s about the only redeeming quality here. For the price they charge, you'd expect a much better experience. Sadly, this feels like what you'd call a classic ‘tourist trap’. We left without finishing our meal as it was just so unpleasant. It has gone from ok to bad to worse over the last 3 years. Yes Definitely better options elsewhere. 🙃",
#     'time': 1727130798,
#     'translated': False},
#    {'author_name': 'Beāte Dementjeva-Dedele',
#     'author_url': 'https://www.google.com/maps/contrib/113493058118379848230/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a/ACg8ocKue5yYN49s1bi-TsOyyQRsh9CQb0JXAgRAtqp5h1z2ydMWSQ=s128-c0x00000000-cc-rp-mo',
#     'rating': 2,
#     'relative_time_description': '2 weeks ago',
#     'text': "Honestly, the food was underwhelming — ended up with an upset stomach afterward. The service? Let's just say it left much to be desired. The view is nice, but that’s about the only redeeming quality here. For the price they charge, you'd expect a much better experience. Sadly, this feels like what you'd call a classic ‘tourist trap’. Definitely better options elsewhere. 🙃",
#     'time': 1726727948,
#     'translated': False},
#    {'author_name': 'NEWBZ4EVER',
#     'author_url': 'https://www.google.com/maps/contrib/110377962870829833334/reviews',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjVxrK1pyjjMpApU_H9fVPBame2MBbl9vJZYxKacG94J3VNgBGA=s128-c0x00000000-cc-rp-mo',
#     'rating': 5,
#     'relative_time_description': 'in the last week',
#     'text': '',
#     'time': 1728263791,
#     'translated': False},
#    {'author_name': 'Anul Kostanyan',
#     'author_url': 'https://www.google.com/maps/contrib/113549336894332794798/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a/ACg8ocInTUPY4wKR8qmyIxL9KV-ZlSY_5BuWskUDAIBDcN5QiWe7MQ=s128-c0x00000000-cc-rp-mo',
#     'rating': 1,
#     'relative_time_description': 'in the last week',
#     'text': "I recently visited this café and my experience was quite disappointing. The service was extremely slow even though the place wasn't crowded. The staff seemed uninterested and unfriendly. Additionally, the quality of the food and drinks did not justify the high prices. My coffee arrived cold and my sandwich was dry and tasteless. I wouldn't recommend this place to anyone looking for a good café experience.",
#     'time': 1728259668,
#     'translated': False},
#    {'author_name': 'Thierry Charles',
#     'author_url': 'https://www.google.com/maps/contrib/105675825766798855277/reviews',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjUEoFOkUY4UpCZoglOYdzfHXoEQP6ReGJ4Nv8tBhwwdpWMrHhL4=s128-c0x00000000-cc-rp-mo-ba5',
#     'rating': 5,
#     'relative_time_description': 'in the last week',
#     'text': '',
#     'time': 1728193798,
#     'translated': False},
#    {'author_name': 'Marilu Reyes',
#     'author_url': 'https://www.google.com/maps/contrib/102442287633660496459/reviews',
#     'language': 'en-US',
#     'original_language': 'es',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjXNnhI_fnOZV0G_2mycGxUpNyJaWjOi9Lb6dnfP50EQZtBsvf-X=s128-c0x00000000-cc-rp-mo-ba2',
#     'rating': 5,
#     'relative_time_description': 'in the last week',
#     'text': 'It is a very beautiful and very quiet place and the food is delicious 😋',
#     'time': 1728102280,
#     'translated': True},
#    {'author_name': 'mauri',
#     'author_url': 'https://www.google.com/maps/contrib/110230364972941495291/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjVGdN4gkQOHYh_kFVmNjiyJtZoe5UF_DqKd1u7AKj0qFI0EY_ZT=s128-c0x00000000-cc-rp-mo',
#     'rating': 5,
#     'relative_time_description': 'in the last week',
#     'text': 'I’ve never had a view like this while dining in - breathing taking views with outstanding hospitality. This place really is paradise - shoutout to Kathleen and the rest of the staff for making me and my partner’s day! I wish I can return soon :’(',
#     'time': 1728085496,
#     'translated': False}]},
#  {'name': 'Nobu Malibu',
#   'place_id': 'ChIJewC2XzIe6IARgQhofffh6fE',
#   'lat': 34.0390391,
#   'lng': -118.6696477,
#   'reviews': [{'author_name': 'Junshik Ham',
#     'author_url': 'https://www.google.com/maps/contrib/108600463107233170735/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjXiKmUoT0WGG6X8xV2VB_sB24yHuxgrnNiZ_2w4T-WMgYVYOYoI=s128-c0x00000000-cc-rp-mo-ba4',
#     'rating': 4,
#     'relative_time_description': 'a week ago',
#     'text': '[4.3 / 5]\n\nThe iconic Nobu Malibu.\n\nWhile the view, the atmosphere, and service is quite up to par with expectations, it is somewhat hard to justify the rather hefty price. While most of the dishes taste great, the portions are quite small and some tasted just “okay.” That being said, the quality of the dishes and ingredients were undoubtedly great.\n\nWhile the restaurant may not justify the price tag for “non-special” meal, I think it may be worth it for some special occasion.\n\nAlso good to note that they offer valet/parking, while its extremely hard to find a decent parking in Malibu.',
#     'time': 1727166402,
#     'translated': False},
#    {'author_name': 'Jessica Vo',
#     'author_url': 'https://www.google.com/maps/contrib/105670558484561062675/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjUcVXLgqTHAMkhrmt-L502xPrbMGOwe7w77kbYKdZTUX7kODtN2=s128-c0x00000000-cc-rp-mo-ba5',
#     'rating': 5,
#     'relative_time_description': '4 weeks ago',
#     'text': "Wow we were so surprised at some of the portion sizes. Luckily the servers course out your meal by waiting to order some of your food, so I was able to cancel one of my dishes. We left stuffed and happy. The drinks were great and the servers were really fun to interact with. We did make a reservation, but we're able to be seated 45 minutes early when we walked in early.",
#     'time': 1725720907,
#     'translated': False},
#    {'author_name': 'Abdullah Alwatban',
#     'author_url': 'https://www.google.com/maps/contrib/100105678955254169645/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a/ACg8ocJC7vyyKi5SILWAfGgyz-XfIqxSe0ZcLMrSKFpVTwah05QRQw=s128-c0x00000000-cc-rp-mo-ba4',
#     'rating': 5,
#     'relative_time_description': '2 weeks ago',
#     'text': 'As usual Nobu never seises to impress, the environment, view and seating are one of the best i’ve seen in Malibu !!!\nFirst of all i would highly recommend booking in advance (1 month ahead) so you dont risk waiting because it’s usually. The best seating would be their outdoor area with the view of the pacific.\nThe service is spectacular, the waiters are very supportive & knowledgeable by giving great recommendations with quick service.\n\nIn terms of food it’s a traditional Japanese resturant and they do it perfectly !! Every dish we had was perfect and my personal favourite and what i consider a must try is the black cod. There sushi is nice we tried a few choices and they all were very delicious. If you’re into something spicy try the crispy okra.',
#     'time': 1726933962,
#     'translated': False},
#    {'author_name': 'Edwin Cerda',
#     'author_url': 'https://www.google.com/maps/contrib/104854128346220364969/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a/ACg8ocIJWK1C4Xck6uj_ZbcjOmk8cXiq_2gJb5wT6SuCAMFhlAzoXA=s128-c0x00000000-cc-rp-mo-ba4',
#     'rating': 5,
#     'relative_time_description': 'a week ago',
#     'text': 'Took my son here for dinner for his birthday, and everything is good. Reservations are tough but worth it. Everything of fresh and service is amazing. Great atmosphere as well.',
#     'time': 1727412482,
#     'translated': False},
#    {'author_name': 'Garima Gautam',
#     'author_url': 'https://www.google.com/maps/contrib/114395070045588486546/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjXeFdBLhhg6LWmOdOWbbB0jj0W0XpcpryYeQhGQD-h98xsAR69ooA=s128-c0x00000000-cc-rp-mo-ba6',
#     'rating': 5,
#     'relative_time_description': '5 months ago',
#     'text': 'Everything was incredible here! Reservations open one month in advance and actually got lucky and got a sunset reservation which was perfect!! Space is beautiful and well worth spending your time here! As for food, I only tried their vegetarian menu and they do have plenty of options actually but nothing to rave about. However I would go back again for the vibe and views 🥰',
#     'time': 1714164674,
#     'translated': False},
#    {'author_name': 'Leon Tregel',
#     'author_url': 'https://www.google.com/maps/contrib/114085646179157115380/reviews',
#     'language': 'en-US',
#     'original_language': 'de',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a/ACg8ocKS-wy1nH7g0o768YiW4rJgnnzM86tewS72Pj2P0VDTmhp5gw=s128-c0x00000000-cc-rp-mo-ba3',
#     'rating': 4,
#     'relative_time_description': 'in the last week',
#     'text': "Good location right by the sea. The food is good but the price is really high. You can do it when you're there, but it's not worth making the extra trip.",
#     'time': 1728221133,
#     'translated': True},
#    {'author_name': 'Bassam Adonai',
#     'author_url': 'https://www.google.com/maps/contrib/108214283453578019465/reviews',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjWWWL7Mxo-2CJFnIpTq8zXGMgAdbwunYQQfPPbW6P4NFBDY8n0=s128-c0x00000000-cc-rp-mo-ba3',
#     'rating': 5,
#     'relative_time_description': 'in the last week',
#     'text': '',
#     'time': 1728156514,
#     'translated': False},
#    {'author_name': '김상권',
#     'author_url': 'https://www.google.com/maps/contrib/114972487563865148058/reviews',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a/ACg8ocI9QBr-TZ3CZkZvZ31L4rpwgReedWefrCtZ13J85YSpEnfrpg=s128-c0x00000000-cc-rp-mo',
#     'rating': 5,
#     'relative_time_description': 'in the last week',
#     'text': '',
#     'time': 1727841278,
#     'translated': False},
#    {'author_name': 'Joshua Halloran',
#     'author_url': 'https://www.google.com/maps/contrib/101446382524524438508/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjV8YxeNVLT-FGrqtimcdegPXCPoaamhm0gZY_qu3HjOkDdnKPnDVw=s128-c0x00000000-cc-rp-mo-ba4',
#     'rating': 5,
#     'relative_time_description': 'in the last week',
#     'text': 'Everything you’d hope for in a waterfront dining experience! Oceanside seats over the water make for an enchanting meal. Started off spicy edamame, transitioning into yellowtail tail jalapeño sashimi and Albacoreo sashimi in a lemon sauce that both melt in your mouth. Ordered the fillet Toban Yaki for main course…all I can say is wow…the savory blend of soy, mushrooms, steak, and caramelized onions is heaven! Finished it off with a lava cake stuffed with white chocolate mint ganache…incredible! Meal, 4 drinks and tip was about $360. Delightful experience',
#     'time': 1727828710,
#     'translated': False},
#    {'author_name': 'Nouf Ageel',
#     'author_url': 'https://www.google.com/maps/contrib/110985317793003293289/reviews',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a/ACg8ocINwtkxhvSXP3J_FMgFnw__pZtn39Hg7f3lYDXyLoDZ3BXZjg=s128-c0x00000000-cc-rp-mo-ba3',
#     'rating': 5,
#     'relative_time_description': 'in the last week',
#     'text': '',
#     'time': 1727765218,
#     'translated': False}]},
#  {'name': 'Saddle Peak Lodge',
#   'place_id': 'ChIJIWi-LR4g6IARZNRM1sPXDGs',
#   'lat': 34.0782093,
#   'lng': -118.6931594,
#   'reviews': [{'author_name': 'James Johnson',
#     'author_url': 'https://www.google.com/maps/contrib/105729934877493552999/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjU1nl73oPIMgpUKuBh94JYJM1ZVZsZ4Xy4qcXXHyWahs7g5NxdHFQ=s128-c0x00000000-cc-rp-mo-ba5',
#     'rating': 5,
#     'relative_time_description': '4 weeks ago',
#     'text': "The Game Trio is why you come here! Seating inside the lodge or the patio outside, either is nice. Many people prefer outside but inside is also nice with rustic old lodge feel.  Valet parking available. Tucked into the canyon hills location. Their wine prices are high but their clientele probably doesn't care Justin Cabernet is 3x   normal. Great service with helpful suggestions. 1000% recommend the Game Trio! Loved the Elk on that plate. Also the Shishito Peppers appetizer. Portions are good size for the money. This place ain't cheap but the food and atmosphere is worth a special trip.",
#     'time': 1725836807,
#     'translated': False},
#    {'author_name': 'Amy Gottlieb',
#     'author_url': 'https://www.google.com/maps/contrib/101944179459124478393/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjWIU_CHaa0NitVT0vHniW0Y3E1TrHCUyN6rzs1tg5FoeOKo57CMiA=s128-c0x00000000-cc-rp-mo',
#     'rating': 5,
#     'relative_time_description': '7 months ago',
#     'text': 'Everything was beautifully done. The wait staff was incredible. The food was quite good, but some of it way overpriced for the size of the portions. The ambience is both lovely and grotesque. Too many dead animals decorating the place everywhere you look. I know it’s a hunters lodge, but oh my God! It’s everywhere! Rather overwhelming.',
#     'time': 1710025495,
#     'translated': False},
#    {'author_name': 'Gillian Goldman',
#     'author_url': 'https://www.google.com/maps/contrib/106781564308451990036/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjWTZDV8xf6QwNKM0rFlYk7sKiFFBI5OG3ZDVkb1AiycppcGFlO3Kg=s128-c0x00000000-cc-rp-mo-ba5',
#     'rating': 3,
#     'relative_time_description': '10 months ago',
#     'text': 'Haven’t been here in years and wasn’t thrilled About going because I’m not into dead animals on the walls all around and not into gamey meats… however they changed the menu so there are more normal options to choose from. The place is set in the canyon surrounded by oaks and the room is legit log cabin style and even tho the animals are still on the wall it’s a pretty cool environment. Our waiter was great but the guys who actually served the meals were a lot to be desired. They didn’t speak much English and every single time didn’t get the dishes to the right people …it was like they had no idea what they were doing. The food was flavorful but luke warm. I had the filet and I like a steak to come out hot. My husband has the rib eye and his was the same. The Cesar had almost no dressing so we needed to get extra. They also didn’t come around and ask if we wanted refills on our drinks. The best thing was the Johnny cake - which was like having dessert first. The bill was nearly $1000 for 6 so pricey for the level of service etc. …a dinner here Once in a decade is enough.',
#     'time': 1699771394,
#     'translated': False},
#    {'author_name': 'J Dubbs',
#     'author_url': 'https://www.google.com/maps/contrib/117328775680838283979/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjXvvwRjiGYGt9juQJEgzwZ4ec-PuvBpxjVTl1HXSKY-S2ZD1WI=s128-c0x00000000-cc-rp-mo-ba4',
#     'rating': 5,
#     'relative_time_description': '4 months ago',
#     'text': 'A fantastic place to visit. Great service, stellar food. They gave us an experience to remember for our anniversary. Worth every dollar.',
#     'time': 1716537326,
#     'translated': False},
#    {'author_name': 'Kate Petrova',
#     'author_url': 'https://www.google.com/maps/contrib/110131751472381842440/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a/ACg8ocK-Syk_huVQaComT2sNJfkc8GjCPnUWJV7JX3XdRI6twpYKSA=s128-c0x00000000-cc-rp-mo',
#     'rating': 3,
#     'relative_time_description': '12 months ago',
#     'text': "The starters were a disappointment. We ordered a pork belly and a salmon tartare. One of the 3 pieces of pork belly was literally just a piece of fat with no meat at all. Very fatty and greasy, which you would expect of a pork belly, but everything has limits. And then the sauce and that toast - the dish all together had a fast-food taste profile. Do not recommend. The salmon tartare tasted just like lemon and pretty much no other flavor to it. Very plain, not interesting. Absolutely not worth the calorie budget and the money budget too. Game meats, on the other hand, were a pure delight! We ordered a trio plus the quail and a duck breast - everything was just great👌 Elk was tender and delicious, rabbit was flavorful, bison was very bright, and quail... well, that's just a quail, can't expect much from it, but it was good. And I liked the duck breast cooked to perfection with the sweet notes from dark cherries. All meats came with great matching sides - just really good!\nSo if you like me don't like to put mediocre food inside of your body, my good advice to you is skip the starters and go straight to main courses. That's what's worth it! ❤️ I will be back for that game trio for sure!",
#     'time': 1696894262,
#     'translated': False},
#    {'author_name': 'Mike E',
#     'author_url': 'https://www.google.com/maps/contrib/100522056519589789052/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a/ACg8ocJce2uNYKgxvAtsbafWoITqUeBrGeRrnb2rDSsb0dYQdcYa1w=s128-c0x00000000-cc-rp-mo-ba4',
#     'rating': 5,
#     'relative_time_description': 'a week ago',
#     'text': "If you are game for some wild food, this venue is unsurpassed. Pricy, but it's very worth it.",
#     'time': 1727194584,
#     'translated': False},
#    {'author_name': 'enes cihan cinar',
#     'author_url': 'https://www.google.com/maps/contrib/101897829844703948153/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjXjgdPcW8cpFp5vhTuZ8L_v4kglaFaH4Qf3NayvkUMuKVjjvHMD=s128-c0x00000000-cc-rp-mo-ba4',
#     'rating': 5,
#     'relative_time_description': '3 weeks ago',
#     'text': 'The reuben sandwich was really good. Nick the waitress made us feel good with everything. Tahin (a bird) welcomed us well at the valet area.',
#     'time': 1726451354,
#     'translated': False},
#    {'author_name': 'James Johnson',
#     'author_url': 'https://www.google.com/maps/contrib/105729934877493552999/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjU1nl73oPIMgpUKuBh94JYJM1ZVZsZ4Xy4qcXXHyWahs7g5NxdHFQ=s128-c0x00000000-cc-rp-mo-ba5',
#     'rating': 5,
#     'relative_time_description': '4 weeks ago',
#     'text': "The Game Trio is why you come here! Seating inside the lodge or the patio outside, either is nice. Many people prefer outside but inside is also nice with rustic old lodge feel.  Valet parking available. Tucked into the canyon hills location. Their wine prices are high but their clientele probably doesn't care Justin Cabernet is 3x   normal. Great service with helpful suggestions. 1000% recommend the Game Trio! Loved the Elk on that plate. Also the Shishito Peppers appetizer. Portions are good size for the money. This place ain't cheap but the food and atmosphere is worth a special trip.",
#     'time': 1725836807,
#     'translated': False},
#    {'author_name': 'Joseph Eustermann',
#     'author_url': 'https://www.google.com/maps/contrib/111856201227179271782/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjVt9JO82i_UcnwJ-XfKdIIRW1oz26voAPxSsGC3Vhx0fBFAtRnbgQ=s128-c0x00000000-cc-rp-mo-ba4',
#     'rating': 5,
#     'relative_time_description': '4 weeks ago',
#     'text': 'Try it for yourself. Absolutely one of my favorites! Everyone should visit. Grab a beverage, dinner, and take a walk around....maybe  consider becoming a member!',
#     'time': 1725830225,
#     'translated': False},
#    {'author_name': 'Mauro Avila',
#     'author_url': 'https://www.google.com/maps/contrib/102721097327209680512/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a/ACg8ocLN8lXk6kYmVrj5cJrxVYZAY2QVWLAboIPIvZjD3ZcKF8oIzw=s128-c0x00000000-cc-rp-mo',
#     'rating': 5,
#     'relative_time_description': 'a month ago',
#     'text': 'Will return again Sunday Brunch ...enjoy the trio',
#     'time': 1724532034,
#     'translated': False}]},
#  {'name': 'Malibu Seafood Fresh Fish Market & Patio Cafe',
#   'place_id': 'ChIJC0xiTBof6IAR6ZbMPPS9weE',
#   'lat': 34.0338129,
#   'lng': -118.7350788,
#   'reviews': [{'author_name': 'Bryan Vadhin',
#     'author_url': 'https://www.google.com/maps/contrib/108957855178446778280/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjWP-Dcki71fGPiQdYok-rwJJRUxovEoTNqKfeNYu08lFeW8HmTN7A=s128-c0x00000000-cc-rp-mo-ba5',
#     'rating': 5,
#     'relative_time_description': '2 weeks ago',
#     'text': "Overall the place is pretty good. The service is a bit awkward but I think it was also just hard for them to hear with all the noise so make sure to speak up politely. I usually don't like not crispy fries but I actually really liked the fries with my fish and chips. The batter is pretty good while it's hot but falters quickly after. Fish is moist too. The clam chowder is really good in my humble opinion but I've only had a few across the years. The view from the place is really really nice though if you could catch sight of a dolphin or few in the water. There's also plenty of outdoor seating so you can really feel the ocean blasting your face. Would definitely come back to try other things if I'm in the area.",
#     'time': 1726988148,
#     'translated': False},
#    {'author_name': 'Sarkis Mazmanian',
#     'author_url': 'https://www.google.com/maps/contrib/104991956741758357585/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a/ACg8ocKXVaGjObY8mKHmWmPi6RmwDId9EjIIBurTUCZI0vZ6dDZUgQ=s128-c0x00000000-cc-rp-mo-ba4',
#     'rating': 4,
#     'relative_time_description': 'a month ago',
#     'text': 'Malibu seafood is a fish market where you can actually order food to be prepared and eat at the location. They only have outdoor seating where you seat yourself and the popular spot to sit at is at the patio which is elevated and comes with a great view.\n\nIt was a Sunday afternoon after a day at the beach when we came Malibu Seafood for a late lunch with friends. To start off there is definitely a line, we waited roughly 20 minutes to put in our order, and a long line means a lot of orders so we waited almost 40 minutes to get our food. When you order you get a ticket and there is a speaker system used when the order is ready to be picked up at the window.\n\nWe ordered the 2 piece fish & chips, the lobster roll, New England clam chowder and trout. The food had no issues. The New England clam chowder had a generous amount of clams, tasted good and was served piping hot. The fish and chips tasted good, was a decent portion and served hot, the fries were on the thicker side and tasted decent. The lobster roll is definitely one to order again. The trout did not live up to its price tag. There is a relatively large menu to choose from so feel free to explore.\n\nThere was a little parking lot which was completely full but rotated frequently enough where a spot would have probably opened up eventually if we waited long enough, but we found parking on the street, which is PCH.\n\nOverall, it’s a decent spot with decent food, great for wrapping up a day at the beach. We’ve been here multiple times and plan to go many time more in the future.',
#     'time': 1724357121,
#     'translated': False},
#    {'author_name': 'Michael Farley',
#     'author_url': 'https://www.google.com/maps/contrib/110561548851667872472/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjUlqNOGgSt35PSQnLWu7F8at_cfho9kKDUbxVmHnQnFTZa7oryIRg=s128-c0x00000000-cc-rp-mo-ba5',
#     'rating': 5,
#     'relative_time_description': 'a month ago',
#     'text': 'Is NOT $10-$20 per person average, as google maps implies. My wife and I, just two of us, spent $60.34 without any drinks, and before tip, (see receipt pic).\nExpect parking to be difficult on Sat, Sun, or Holiday, and line to be long to get inside to order. We spent about 20 minutes in the line.\nOkay, now the good. Even though it was a busy Saturday lunch time, we received our To-Go order in 19 minutes, not bad. The food was all well prepared and tasted good. We ordered the Seafood Combo, 3-piece Fish and Chips, and 8oz Clam Chowder. It all tasted pretty good. We will be back again.',
#     'time': 1724547422,
#     'translated': False},
#    {'author_name': 'Gio Lee',
#     'author_url': 'https://www.google.com/maps/contrib/112648328239777023905/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjWMJhPLamqcwXjUzvHcuqeH16SgBUHIP-B09Q66_VpQ4b5eJoPe=s128-c0x00000000-cc-rp-mo-ba5',
#     'rating': 5,
#     'relative_time_description': '3 months ago',
#     'text': 'Super seafood restaurant worth every penny.    Fish, clam, shrimp, and sides are all great.  They have many selections, and the staffs were super helpful with decisions. Definitely would go back.\nI wish they sold beer.\n\nStaffs are super good, but parking is not very convenient.\n\nChildren also loved the place.',
#     'time': 1720396790,
#     'translated': False},
#    {'author_name': 'Edward Blazejewski',
#     'author_url': 'https://www.google.com/maps/contrib/115445284151217620615/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjVdZWjFBL-rl3KSpESzqL4RQfv079ule6odH3N0naFnrodd0GUu=s128-c0x00000000-cc-rp-mo-ba3',
#     'rating': 5,
#     'relative_time_description': '2 months ago',
#     'text': "We ordered a bunch of items for lunch: the fish and chips, lobster roll, and a cup of clam chowder. We were very excite to try the lobster rolls, but were ultimately disappointed. It was nothing special for $30 a roll, save your money. The best part of the meal was the fish and chips. We ordered two pieces and it was plenty for my fiancée and I. The batter was delicious and the fish was very juicy. I haven't had many fish and chips platters, but this was certainly the best. The fries and coleslaw were also great pairings. The Clam chowder was also delicious, different from what we were used to, but still very good. This is a great place to stop for lunch along Pacific Coast Highway. The line can get long, but the service is quick and there is plenty of seating. I recommend parking along the road to avoid having to pay for the lot.",
#     'time': 1723070168,
#     'translated': False},
#    {'author_name': 'Bill Thomas',
#     'author_url': 'https://www.google.com/maps/contrib/100211748944295373334/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a/ACg8ocKPV0bPHg37f-wTlX7IkCh3--Ne0YIYVQhUfQjiqocW7koFPQ=s128-c0x00000000-cc-rp-mo-ba3',
#     'rating': 5,
#     'relative_time_description': 'in the last week',
#     'text': 'The freshest and tastiest seafood.',
#     'time': 1728183158,
#     'translated': False},
#    {'author_name': 'Arlee Pryor',
#     'author_url': 'https://www.google.com/maps/contrib/103979576049149202303/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjVkVAoWsLgifeo9vQVbc3pXh9GD2IGtubdlsE8YVKlI4erGdu17=s128-c0x00000000-cc-rp-mo',
#     'rating': 5,
#     'relative_time_description': 'in the last week',
#     'text': 'Don’t miss this spot!',
#     'time': 1728163893,
#     'translated': False},
#    {'author_name': 'Chaunsumlit',
#     'author_url': 'https://www.google.com/maps/contrib/108339547452899483944/reviews',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a/ACg8ocJX-UhA3vR5Od-eREO8q9bPdwyamAQRaEY1vE48Kyf6Ruv-i8g=s128-c0x00000000-cc-rp-mo-ba2',
#     'rating': 5,
#     'relative_time_description': 'in the last week',
#     'text': '',
#     'time': 1728106193,
#     'translated': False},
#    {'author_name': 'Drew Hahn',
#     'author_url': 'https://www.google.com/maps/contrib/113449949263295075483/reviews',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjVqQUZAIQU1t1wY66UnzciIjF-il2iZEGgbMRfnXmI9gNDQUJr0gQ=s128-c0x00000000-cc-rp-mo-ba5',
#     'rating': 5,
#     'relative_time_description': 'in the last week',
#     'text': '',
#     'time': 1728055285,
#     'translated': False},
#    {'author_name': 'Michael Ong',
#     'author_url': 'https://www.google.com/maps/contrib/113756196827913439761/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjVrCdbGAcfQxPB0A-EGE92Wsj6piNJutVz6pGAyVpmFrfsNua0Gkg=s128-c0x00000000-cc-rp-mo-ba6',
#     'rating': 5,
#     'relative_time_description': 'in the last week',
#     'text': "Fantastic views, I'd you are lucky you may see dolphins or whales passing by. We love the seafood too. BYOB!",
#     'time': 1728014275,
#     'translated': False}]},
#  {'name': "Duke's Malibu",
#   'place_id': 'ChIJG0Rdz-WgwoARkFKjcvcFARU',
#   'lat': 34.0364534,
#   'lng': -118.6358631,
#   'reviews': [{'author_name': 'Nancy Reinhart Buenrostro',
#     'author_url': 'https://www.google.com/maps/contrib/106046191171195617674/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjXK3y9TpCJFZXjHLv9TYYBUSJJZpTaciOKw1SSHkUnAfAFEbkqSWQ=s128-c0x00000000-cc-rp-mo-ba6',
#     'rating': 5,
#     'relative_time_description': '3 weeks ago',
#     'text': 'You are off for the day, it’s 106 degrees in Camarillo, and you want to get away for the day. You drive the iconic Highway 1 past the packed state beaches looking at the cerulean waters of the Pacific.  Pulling off the highway with precaution, you turn your convertible ( You wish!) over to the valet and enter Duke’s.  Imagine transporting to Hawaii for a few hours and sitting right on the water. Everyone is in Hawaiian attire  and is happy and friendly and offering Hawaiian libations with pineapple and lavender and other exotic combinations. The menu offers up steaks and Hawaiian plate lunches. Top it off with Hula or key pie for a very memorable afternoon!',
#     'time': 1725897479,
#     'translated': False},
#    {'author_name': 'Daniel Mozes (DaDa)',
#     'author_url': 'https://www.google.com/maps/contrib/106857634771769902209/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjUcrtsOvWOeTJvQRVt-IW2nTgzy0Iq3jZlpnSeQxt9b8zOeP4eqGg=s128-c0x00000000-cc-rp-mo-ba3',
#     'rating': 5,
#     'relative_time_description': 'a month ago',
#     'text': "My wife and I decided to take a day off of work and go to the beach so we took full advantage of the opportunity and away we go. We went to the beach for a few hours and then we planned on coming to Dukes in Malibu for lunch date and the view of the ocean which was so beautiful. I got the prime sirloin steak and fries with a side salad and it was really delicious.  The server was really nice and accommodating.  As you could see in the pictures, there's plenty of seating inside the restaurant and they have an attached party space for large groups of people who wanna rent out the space.  The ambience at Dukes is very chill and relaxing with a view of the ocean. I mean how can it get better than that?  There is no street parking as far as I can tell and only a valet parking lot in front of the restaurant that was the only downside of Dukes.  I would definitely recommend Dukes for anybody who's in Malibu and wants to have a good lunch or dinner with the view of the ocean.  Amen and yes please.",
#     'time': 1724093903,
#     'translated': False},
#    {'author_name': 'baxterglen',
#     'author_url': 'https://www.google.com/maps/contrib/111866681016603765230/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a/ACg8ocI0Yy_-Vs0efE8vhIFJQ34or9KizR7esteF9ZxEckpjM6B9_A=s128-c0x00000000-cc-rp-mo',
#     'rating': 5,
#     'relative_time_description': 'in the last week',
#     'text': 'Rae was a great hostess. Happy early birthday. Toby took care of us well.\n\nThe food selection was diverse. Each item we ordered was delicious.\n\nThe View of course was beautiful.\n\nDefinitely recommend this location.',
#     'time': 1727906181,
#     'translated': False},
#    {'author_name': 'Lori P.',
#     'author_url': 'https://www.google.com/maps/contrib/116433769986725951639/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjWNnagF07pGlrTTmow1xQnf2Rsyq7c5YczXmUgCWXERGrhPvLkMpQ=s128-c0x00000000-cc-rp-mo-ba3',
#     'rating': 5,
#     'relative_time_description': 'a month ago',
#     'text': 'Go here for Great views, friendly service and delicious food. We got there before it opened and there were at least 20 people waiting… a good sign. The food and drinks were amazing and the flavors were perfectly paired and at the appropriate intensity. I had the steak & fries and my date had the mango bbq burger. Both were cooked perfectly and came out hot and fresh. Must visit again to try their Volcano frozen cocktail.',
#     'time': 1723515320,
#     'translated': False},
#    {'author_name': 'R D',
#     'author_url': 'https://www.google.com/maps/contrib/100854990148846875373/reviews',
#     'language': 'en',
#     'original_language': 'en',
# ...
#     'time': 1709261450,
#     'translated': False},
#    {'author_name': 'Gabriel Barrandeguy (gabaktech)',
#     'author_url': 'https://www.google.com/maps/contrib/114652628021119204632/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjVMoruSC0sHVf8nftY6K_mfCq7X_5u23ZDtdmPNwK7UGecjZ9jfHw=s128-c0x00000000-cc-rp-mo-ba5',
#     'rating': 5,
#     'relative_time_description': '5 months ago',
#     'text': 'Amazing service\nWaitress knows about food like the keto diet\nThey have Himalayan salt pink salt\nAsparagus and  the steak was amazing\nAlso they vinegar to add to my Water',
#     'time': 1712890204,
#     'translated': False},
#    {'author_name': 'Walter “The Lighting Guy” Jukes',
#     'author_url': 'https://www.google.com/maps/contrib/103484471959958920749/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a/ACg8ocLDadv3h3ITQHSbaJiJEAJWgr_6-ZEdmL1azMv3q3Y1Hs6Kz-ga=s128-c0x00000000-cc-rp-mo-ba5',
#     'rating': 5,
#     'relative_time_description': '3 weeks ago',
#     'text': 'Very good steaks . My moms birthday, so i took her the expensive place i could think of, so it was mcdonalds or flemmings . They both now and days cost about the same, lol jk.  Great place for a real good steak, and they take ggod care of you.',
#     'time': 1726458286,
#     'translated': False},
#    {'author_name': 'Yutaka',
#     'author_url': 'https://www.google.com/maps/contrib/118322269599711790620/reviews',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjUSkqB250L_hyKR_7mpgKmjHFX8T5hxwomswUDkra6eH5ORFBgHMw=s128-c0x00000000-cc-rp-mo-ba4',
#     'rating': 4,
#     'relative_time_description': 'a month ago',
#     'text': '',
#     'time': 1725420266,
#     'translated': False},
#    {'author_name': 'David Brand',
#     'author_url': 'https://www.google.com/maps/contrib/108373377432226286297/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjUSO3_g2--nLntvy_EAlv_1u1g7-yd2mO-FvuKMDQM-7vwsII4_=s128-c0x00000000-cc-rp-mo-ba4',
#     'rating': 5,
#     'relative_time_description': 'a month ago',
#     'text': 'Love going there. Great food and great service!',
#     'time': 1725056243,
#     'translated': False},
#    {'author_name': 'Brandon Saranik',
#     'author_url': 'https://www.google.com/maps/contrib/110177476960505949164/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjXDwjHDIaF2Sm3gZg0SShOzcvVds89SA2lPbaMf4Sz74hlgNSPe=s128-c0x00000000-cc-rp-mo',
#     'rating': 2,
#     'relative_time_description': 'a month ago',
#     'text': 'Fleming’s on Topanga Canyon underwent a total remodel inside and all I can say is, what the heck were they thinking?? The lights are SO bright and the music is so loud and cheesy (Top 40 playlist). It doesn’t feel like a premium steakhouse at all anymore. They might have been going for “modern” and “trendy” but achieved neither. It felt cheap, uncomfortable and off putting. To their credit, the waitstaff couldn’t have been nicer but they were unable to adjust the lights or music due to corporate’s instruction. We hope they will address this feedback quickly, and have to imagine other guests have shared similar feedback. We are frequent diners at this location but will not be back unless the atmosphere changes. Again, I don’t want this to take anything away from the staff who were amazing!!',
#     'time': 1723745031,
#     'translated': False},
#    {'author_name': 'Debbie Cortez',
#     'author_url': 'https://www.google.com/maps/contrib/110416122356091218500/reviews',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a/ACg8ocIGGBg6AqO7EaOLL_N1noueXvQcaGXrB4z-4-cVj2y2nMWufQ=s128-c0x00000000-cc-rp-mo',
#     'rating': 5,
#     'relative_time_description': '2 months ago',
#     'text': '',
#     'time': 1722285690,
#     'translated': False}]},
#  {'name': "Morton's The Steakhouse",
#   'place_id': 'ChIJk7kA8x2cwoARQDfcDJOA4Mk',
#   'lat': 34.1845269,
#   'lng': -118.5971283,
#   'reviews': [{'author_name': 'Michael Han',
#     'author_url': 'https://www.google.com/maps/contrib/109013947771483713211/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a/ACg8ocL1TWG8QRvRHDHLW22v-D3H-lJhmZNl-UrwxxezcB1Ch9C6=s128-c0x00000000-cc-rp-mo-ba6',
#     'rating': 5,
#     'relative_time_description': '3 months ago',
#     'text': "Reason for visiting: early Fathers day dinner\n\nDate/time of visit:\xa0Friday night, ~ 7:00 PM\n\nParking:\xa0valet, $8; no validation offered. There's public parking too but when I attempted, the gate was open so didn't get a ticket so I thought it was free. When I entered, gate closed behind and I was stuck with no ticket; had to call for help and took ~5 mins to get out. Was going to go back in but decided to skip all that madness and valet. Not sure how much public parking wouldve been. If you don't have cash for valet, you can also charge it your bill\n\nParty size: 7; 2 teens\n\nEnvironment/ambience:\xa0was a little loud. We sat near the kitchen so maybe that's why. Bathroom was clean. Pretty crowded; reservations are needed. There's a dress code too; no shorts, slippers, or clothes that smell or give off an odor. Not sure if it's enforced.\n\nService: was great; she came around often and food was cooked as requested, with no issues. All steaks were cooked Medium-Rare. Folded napkin when I stepped away to restroom and came back 😀\n\nFood:\xa0had the Prime NY strip (not dry aged), Parmesan Truffle Fries, Old Fashioned, Seafood Tower (lobster tail, Oyster, Tuna), Cream Corn, Lobster Mac N' Cheese, and Creme Brulee. Everything was good.\n\nCost: $1140, including tip.\n\nWould I go back (yes/no): 90/10",
#     'time': 1718490823,
#     'translated': False},
#    {'author_name': 'Mackenzie Emi',
#     'author_url': 'https://www.google.com/maps/contrib/110650172332922288863/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a/ACg8ocIX_KL9wSd84SxbnydfaAKfujpgog12NfzyCSA-6t7SMJ1tCg=s128-c0x00000000-cc-rp-mo',
#     'rating': 4,
#     'relative_time_description': 'a month ago',
#     'text': 'My husband surprised me by taking me here for my birthday dinner. The food was very good but truly the service is what made this meal so great. Derek was an EXCEPTIONAL server. Very personable, professional and kind. He gave great recommendations (the lamb and the lava cake are delicious!) and made us feel very taken care of. Will happily be back!',
#     'time': 1723274841,
#     'translated': False},
#    {'author_name': 'IVAN MARCAL',
#     'author_url': 'https://www.google.com/maps/contrib/113084074585108655338/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a/ACg8ocJtSeDJ2-gdmzlP2MptIpyQEpOZbKiXe3zzLTa165dJAlhsQQ=s128-c0x00000000-cc-rp-mo-ba2',
#     'rating': 5,
#     'relative_time_description': '4 months ago',
#     'text': '🌟 Review: Morton’s Woodland Hills 🌟\n\nI just had the most amazing dining experience at Morton’s Woodland Hills yesterday! From the moment we walked in, the outstanding customer service set the perfect tone for our evening. Our server, Danny, truly deserves a five-star rating - attentive and friendly, he made our celebration extra special.\n\nYesterday, we were there to celebrate a birthday, and we were blown away by how accommodating they were. Not only did they offer exceptional food, but they even provided a bowl for my little dog, ensuring that everyone in our party felt welcome and taken care of.\n\nThe food was beyond exceptional, and every bite was pure perfection. If you’re looking for a memorable dining experience with outstanding customer service, Morton’s Woodland Hills is a place to be!!',
#     'time': 1715802922,
#     'translated': False},
#    {'author_name': 'Sheila Martinez (Sheiila)',
#     'author_url': 'https://www.google.com/maps/contrib/105841628000296493982/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjV73wP9VlxXSU7xZjWXzxSLkkqtI0L6-eREmDlpxc4Hf90WwFvfgg=s128-c0x00000000-cc-rp-mo-ba4',
#     'rating': 5,
#     'relative_time_description': 'a year ago',
#     'text': 'Brenda was absolutely amazing! Not only did she give us a great private table for our date but her service was beyond words. The atmosphere is very quiet and perfect to have conversations. The food was delicious, compliments to the chef! Definitely know what they’re doing. The drinks could use a little bit of work but nonetheless everything was perfect. Thank you! We will be back.',
#     'time': 1681623401,
#     'translated': False},
#    {'author_name': 'Dorothy Hoffman',
#     'author_url': 'https://www.google.com/maps/contrib/114449596973557543124/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjUEw_WqDpk5LLrToMrKHCI5jiDlQop3bgRek-oI_Ax-txnpnbw=s128-c0x00000000-cc-rp-mo-ba3',
#     'rating': 5,
#     'relative_time_description': 'a month ago',
#     'text': "It's a great place for a special event. We celebrated a 60th birthday there and it's one of those places that prints a message onto the menu and presents them to you at the end. Staff knew we were there for a birthday and multiple members wished my husband Happy Birthday. Tbh, I considered giving the food a 4, but it was just a reminder that when you go to a steakhouse order steak, not lobster.",
#     'time': 1724605933,
#     'translated': False},
#    {'author_name': 'Leila Shay',
#     'author_url': 'https://www.google.com/maps/contrib/101335861104923284663/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjWCjjoF8rpjL7vBvxbt9Fv4THX9rGHqG99_3U1vXN5ef9upoPi9=s128-c0x00000000-cc-rp-mo-ba4',
#     'rating': 4,
#     'relative_time_description': 'in the last week',
#     'text': 'We ordered chopped house salad for appetizer , filet mignon and prime Cajun ribeye with backed potato and chocolate cake with ice cream for dessert.\nThe problems were Both Steaks were too salty specially the Cajun ribeye.\nAnd the salad had a lot of blue cheese on it.\n\nParking is just valley parking and it costs $8.',
#     'time': 1728149865,
#     'translated': False},
#    {'author_name': 'Joshua Finkel',
#     'author_url': 'https://www.google.com/maps/contrib/113966552409636637169/reviews',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjVa9nrlvFdc_vYt59XTK3aG9HaAp2VnrPDiu5E0BrkU55zmLkP5Hg=s128-c0x00000000-cc-rp-mo-ba5',
#     'rating': 5,
#     'relative_time_description': 'in the last week',
#     'text': '',
#     'time': 1728098933,
#     'translated': False},
#    {'author_name': 'Gerald p',
#     'author_url': 'https://www.google.com/maps/contrib/109888329898344572014/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjX4cs7NhKBSFPtgdWawouepwEMsZRjXiPU9fkp-ajyKV4Bd3Jw=s128-c0x00000000-cc-rp-mo-ba4',
#     'rating': 4,
#     'relative_time_description': 'a month ago',
#     'text': 'Had the filet and lobster, very good. Service and atmosphere was great. Sorry forgot pictures',
#     'time': 1725292430,
#     'translated': False},
#    {'author_name': 'donna allyn',
#     'author_url': 'https://www.google.com/maps/contrib/112464271197056460573/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a/ACg8ocJRA5HMmlEHO1bYOemcuLZk-0SO0xBEbP9yM87qC2rIBsGS9A=s128-c0x00000000-cc-rp-mo',
#     'rating': 3,
#     'relative_time_description': 'a month ago',
#     'text': "update from 2024...Kirk our server was friendly and attentive.  The Caprese salad, Wagyu filet, and creme brulee were all great.  The shrimp calabria had zero flavor and the shrimp did not taste fresh.  The green beans tasted like the just had Sambal paste dumped on them and they were cold.  Sent them back to be heated.  Suspect the beans by themselves would have been excellent as they looked very young and fresh.  The onion rings are nothing to brag about especially since they looked and tasted like frozen rings.   We like dining on the patio in the fresh air.\n\nfrom 2022 Unfortunately this was one of the worst experiences we've had at the Woodland Hills location.  We dined outside on the patio as in the past.  It took approx 30 minutes to bring the bread and our drinks and then Jay our server brought a red wine for Jim (he ordered a chardonnay) and my wine carafe had hair in it.  Both drinks were replaced.  It took THREE requests for Jay to fix our wobbly table; 1st time he said the busser would fix it, then said the manager would 2 times.  Had to ask for water refills.  He did not know the menu after six months at Mortons; he claimed the patio menu was different - it's not.  My shrimp Alexander was lukewarm.  He brought my husband's requested desert but never asked me what I wanted for desert.  Fortunately my husband's birthday dinner entree Wagyu was excellent.  Sadly the returned red wine was on our bill and had to ask to have it removed - did not receive a corrected bill.  Jay knew my husband is a LSC member and Jay claimed he had all the info from the hostess desk, yet we had to ask for the $25 bday reward to be included in the final check.  As much as we usually enjoy Landrys, this experience makes it difficult to want to return.",
#     'time': 1725218887,
#     'translated': False},
#    {'author_name': 'Dorothy Hoffman',
#     'author_url': 'https://www.google.com/maps/contrib/114449596973557543124/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjUEw_WqDpk5LLrToMrKHCI5jiDlQop3bgRek-oI_Ax-txnpnbw=s128-c0x00000000-cc-rp-mo-ba3',
#     'rating': 5,
#     'relative_time_description': 'a month ago',
#     'text': "It's a great place for a special event. We celebrated a 60th birthday there and it's one of those places that prints a message onto the menu and presents them to you at the end. Staff knew we were there for a birthday and multiple members wished my husband Happy Birthday. Tbh, I considered giving the food a 4, but it was just a reminder that when you go to a steakhouse order steak, not lobster.",
#     'time': 1724605933,
#     'translated': False}]}]

# %%
with open("restaurants_info.json", 'r') as f:
    restaurant_info = json.load(f)

print(restaurant_info)
# Out:
# [{'name': "Geoffrey's", 'place_id': 'ChIJHRDtTtIY6IAR1xN4Fw2fiGA', 'lat': 34.0253497, 'lng': -118.7698216}, {'name': 'Paradise Cove Beach Café', 'place_id': 'ChIJwbruq90Y6IARYuzvcpV-dYc', 'lat': 34.0202609, 'lng': -118.7872024}, {'name': 'Nobu Malibu', 'place_id': 'ChIJewC2XzIe6IARgQhofffh6fE', 'lat': 34.0390391, 'lng': -118.6696477}, {'name': 'Saddle Peak Lodge', 'place_id': 'ChIJIWi-LR4g6IARZNRM1sPXDGs', 'lat': 34.0782093, 'lng': -118.6931594}, {'name': 'Malibu Seafood Fresh Fish Market & Patio Cafe', 'place_id': 'ChIJC0xiTBof6IAR6ZbMPPS9weE', 'lat': 34.0338129, 'lng': -118.7350788}, {'name': "Duke's Malibu", 'place_id': 'ChIJG0Rdz-WgwoARkFKjcvcFARU', 'lat': 34.0364534, 'lng': -118.6358631}, {'name': 'Taverna Tony', 'place_id': 'ChIJE5TqjTIe6IAREtbysD5fqXE', 'lat': 34.0365955, 'lng': -118.6859276}, {'name': 'Subway', 'place_id': 'ChIJDzEfbjQe6IARsaKr2kOTpw0', 'lat': 34.03413159999999, 'lng': -118.6913849}, {'name': 'Ollo', 'place_id': 'ChIJr6hDqkwe6IARSTn4xwtNsAg', 'lat': 34.034147, 'lng': -118.693057}, {'name': 'SunLife Organics', 'place_id': 'ChIJKxOkjfYY6IAR-a-R5tNc5vU', 'lat': 34.0213559, 'lng': -118.809599}, {'name': 'Gravina Malibu', 'place_id': 'ChIJD2FCLvAY6IARoYOIqR6HN1E', 'lat': 34.0218198, 'lng': -118.8023202}, {'name': 'Malibu Farm Pier Cafe', 'place_id': 'ChIJTZbPtyse6IARnWiKAUms3LA', 'lat': 34.0356151, 'lng': -118.6756299}, {'name': 'Marmalade Cafe', 'place_id': 'ChIJDceIcDIe6IARpwSMNeVNvGY', 'lat': 34.03527070000001, 'lng': -118.6842264}, {'name': 'Starbucks', 'place_id': 'ChIJBxVwZQ4Y6IARYwRGcXEj714', 'lat': 34.03119220000001, 'lng': -118.8431336}, {'name': 'Tra di Noi', 'place_id': 'ChIJewC2XzIe6IARXI_lkK31E4E', 'lat': 34.0357975, 'lng': -118.6863831}, {'name': 'Starbucks', 'place_id': 'ChIJNafc-DQe6IAR1G0PxUYio6Y', 'lat': 34.0339747, 'lng': -118.693388}, {'name': "Lily's Malibu", 'place_id': 'ChIJX1Gc9fYY6IAR4rR1xuHYExk', 'lat': 34.0212829, 'lng': -118.8099614}, {'name': 'Jack in the Box', 'place_id': 'ChIJh0y6vSse6IARlvWdO3BLd2g', 'lat': 34.0373933, 'lng': -118.6775029}, {'name': 'Cafe Habana', 'place_id': 'ChIJTaJLbTIe6IAR3geAnwz1fd4', 'lat': 34.0345715, 'lng': -118.6856283}, {'name': 'Sunlife Organics', 'place_id': 'ChIJG_SEYDIe6IARHfeyKZFiHi0', 'lat': 34.035764, 'lng': -118.685696}, {'name': 'The Malibu Cafe', 'place_id': 'ChIJibxzhAYj6IART8OKIN6fGd4', 'lat': 34.0916894, 'lng': -118.8172405}, {'name': "D'amores Pizza", 'place_id': 'ChIJpVw0jPYY6IARd7kbDBcQrV8', 'lat': 34.0214039, 'lng': -118.8096214}, {'name': 'Calamigos Ranch', 'place_id': 'ChIJk5FzygYj6IARXHa8eG3QqsQ', 'lat': 34.092137, 'lng': -118.817412}, {'name': 'Spruzzo Restaurant & Bar', 'place_id': 'ChIJ0TeJJ1oY6IARNuXExqzvcvw', 'lat': 34.0168215, 'lng': -118.8190625}, {'name': "Kristy's Malibu", 'place_id': 'ChIJqaEvtFkY6IARPXj6hI7dzRI', 'lat': 34.03163519999999, 'lng': -118.8427484}, {'name': '86 All Day', 'place_id': 'ChIJI-KvDvcZ6IARoWZKY6HXcAc', 'lat': 34.0218037, 'lng': -118.8022642}, {'name': 'The Sunset Restaurant', 'place_id': 'ChIJoUWY828Z6IAREnjpkLUDyOk', 'lat': 34.0111749, 'lng': -118.8166924}, {'name': 'Zuma Cafe', 'place_id': 'ChIJx8-tU0IY6IARZ7cU7LutfFk', 'lat': 34.0207014, 'lng': -118.8288971}, {'name': 'Sabor A Malibu food Truck', 'place_id': 'ChIJTeR82WMj6IAR6pEIQpUSX-Y', 'lat': 34.03548809999999, 'lng': -118.8523864}, {'name': 'The Malibu Market', 'place_id': 'ChIJdRmv42sj6IARHQxWBLaN4Ug', 'lat': 34.0959926, 'lng': -118.8143877}, {'name': 'HAWC café and dining space', 'place_id': 'ChIJ7VzqOoQf6IARlZBenLEHqGc', 'lat': 34.0402405, 'lng': -118.7080341}, {'name': 'Rock Store', 'place_id': 'ChIJ48p3tcAj6IARe3Uq-Bt1hfs', 'lat': 34.1095555, 'lng': -118.7881323}, {'name': 'Old Place', 'place_id': 'ChIJw_xW1cIj6IARix6Utk5iZFE', 'lat': 34.114617, 'lng': -118.778185}, {'name': 'Moonshadows Malibu', 'place_id': 'ChIJLbXg4hihwoARwE802F81zfg', 'lat': 34.0375286, 'lng': -118.6186723}, {'name': 'Gladstones Restaurant', 'place_id': 'ChIJ08qT1PKjwoARY8Fo8DyaBwY', 'lat': 34.038365, 'lng': -118.556626}, {'name': 'Inn of the Seventh Ray', 'place_ ...

# %%
len(data)
# Out:
# 1008

# %%
len(res)
# Out:
# 2014

# %%
len(restaurant_info)
# Out:
# 2014

# %%
for x in res:
    for d in data:
        if d['place_id']
        res[53]['result']['place_id']
# Out:
# 'ChIJoUWY828Z6IAREnjpkLUDyOk'

# %%
res[0]['result']['reviews']
# Out:
# [{'author_name': 'Peter Xaymountry',
#   'author_url': 'https://www.google.com/maps/contrib/107152190076731796260/reviews',
#   'language': 'en',
#   'original_language': 'en',
#   'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjW4-iw-e0tHl9zEINryHZo0RHkxSU2aUq1A5Ys5v7J6GgxmO6ZN=s128-c0x00000000-cc-rp-mo-ba7',
#   'rating': 4,
#   'relative_time_description': '3 weeks ago',
#   'text': "You come here for the view of the beach which is the main attraction especially if you get a good seat. I decided to take my wife here for her birthday so I made reservations ahead of time off OpenTable and told them we were celebrating a birthday so I wanted a table with good view of the water. We arrived early and use their valet parking because it's easier than finding street parking. The valet cost is already added to your bill so you don't have to worry about cash except for tip. We arrived early so we took advantage on walking down to the beach first. We checked in like 20 minutes before our reservation time but they were still able to seat us with a great table with good view of the water. Our waiter was Marvin and we thought he was great with us beside not telling me that the soda is not free refill. That was my only complaint with him but I didn't want to dispute so I just paid it but give less in the tip. My wife got the Pan Seared Chilean Sea Bass for her entree and a Georgia Peach martini for her drink. I got their Herb Crusted Salmon and ask for french fries for my sides. My wife loved her peach martini and of course her Sea Bass. I thought the Salmon was a bit dry and didn't have much favor but Marvin came around asking if I wanted crushed black pepper so I asked for that on the Salmon and fries. It helped a little but not that much to me. We finish off the night with a ice cream dessert where Marvin sang Happy Birthday to my wife. I would recommend coming here and making reservations if you want to experience a good view and some good food but just know that the soda does not have free refills.",
#   'time': 1725852601,
#   'translated': False},
#  {'author_name': 'Carman Carter',
#   'author_url': 'https://www.google.com/maps/contrib/101520279057737812167/reviews',
#   'language': 'en',
#   'original_language': 'en',
#   'profile_photo_url': 'https://lh3.googleusercontent.com/a/ACg8ocIKKaN7Ul4FlHA_qDnQcSiu3zwUyig_utY7Z6wwzAx7LOPN_g=s128-c0x00000000-cc-rp-mo-ba5',
#   'rating': 5,
#   'relative_time_description': 'a month ago',
#   'text': 'Geoffrey’s never disappoints! Been going here since 2001 and this place has not changed much.  Last time here was about 10 years ago.  Still same great service, food, and atmosphere!  Keep in mind if you choose to park on your own, good luck!  Highly recommend either car service or valet. The valet crew is so awesome and as always takes care of everyone with a smile! They were great with our driver. Super polite and accommodating when he dropped us off and picked us up.\nWe love to sit at the bar.  If you do this make sure you sit on the far side so you can see the ocean.  Our bartender was great!  Lots of personality and really enjoyed our time there.\nThe food as always was excellent! We went on a Sunday.  Sat and Sunday they have a great brunch menu.',
#   'time': 1725282499,
#   'translated': False},
#  {'author_name': 'Liz',
#   'author_url': 'https://www.google.com/maps/contrib/116886163617925008970/reviews',
#   'language': 'en',
#   'original_language': 'en',
#   'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjWZnS6QCoPLAi5H79CbNHBMAV0GrOm9UB5RNwt_TKpI54Ldm2pejw=s128-c0x00000000-cc-rp-mo-ba5',
#   'rating': 5,
#   'relative_time_description': 'in the last week',
#   'text': 'First time at this lovely restaurant.  Views and ambience are amazing, they only have valet parking which was $12 not including tip. The service was impeccable, they also did not rush the food service it was at a nice pace. Lovely presentation and food was delicious,  would not hesitate to go back. We were celebrating birthdays.',
#   'time': 1727806644,
#   'translated': False},
#  {'author_name': 'Jennifer Villasenor',
#   'author_url': 'https://www.google.com/maps/contrib/113372860495121882697/reviews',
#   'language': 'en',
#   'original_language': 'en',
#   'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjXxBi2C7_XnjfulHXrIAt7jvpfgGg8XYxJgucH70R6vKX4nUGlDJg=s128-c0x00000000-cc-rp-mo',
#   'rating': 4,
#   'relative_time_description': '3 weeks ago',
#   'text': 'Lovely view, ambiance, and service. I didn’t give it 5 stars because it was good but not amazing. I think the location is the biggest take away. Definitely pricey but not surprising. The waiters were really cool. Parking situation can def get crazy during peak hours . Seems very family oriented which is nice.',
#   'time': 1726352784,
#   'translated': False},
#  {'author_name': 'Shant Khach',
#   'author_url': 'https://www.google.com/maps/contrib/109352422604154094065/reviews',
#   'language': 'en',
#   'original_language': 'en',
#   'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjWm6TJxGt0joahs8kCc6OXUwy3J4tj4XGHfrZtpML1JX1iRXBo=s128-c0x00000000-cc-rp-mo-ba4',
#   'rating': 5,
#   'relative_time_description': 'a month ago',
#   'text': 'Great place with a nice view of the ocean.  They have valet parking and access to the ocean by walking the stairs down. Service is great and good was good too. We enjoyed our time there with our family and kids got happy by playing on the beach after our meal.',
#   'time': 1725297497,
#   'translated': False}]

# %%
res[2]
# Out:
# {'html_attributions': [],
#  'result': {'address_components': [{'long_name': '27400',
#     'short_name': '27400',
#     'types': ['street_number']},
#    {'long_name': 'Pacific Coast Highway',
#     'short_name': 'Pacific Coast Hwy',
#     'types': ['route']},
#    {'long_name': 'Central Malibu',
#     'short_name': 'Central Malibu',
#     'types': ['neighborhood', 'political']},
#    {'long_name': 'Malibu',
#     'short_name': 'Malibu',
#     'types': ['locality', 'political']},
#    {'long_name': 'Los Angeles County',
#     'short_name': 'Los Angeles County',
#     'types': ['administrative_area_level_2', 'political']},
#    {'long_name': 'California',
#     'short_name': 'CA',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'United States',
#     'short_name': 'US',
#     'types': ['country', 'political']},
#    {'long_name': '90265', 'short_name': '90265', 'types': ['postal_code']}],
#   'adr_address': '<span class="street-address">27400 Pacific Coast Hwy</span>, <span class="locality">Malibu</span>, <span class="region">CA</span> <span class="postal-code">90265</span>, <span class="country-name">USA</span>',
#   'business_status': 'OPERATIONAL',
#   'curbside_pickup': False,
#   'current_opening_hours': {'open_now': True,
#    'periods': [{'close': {'date': '2024-10-06', 'day': 0, 'time': '2030'},
#      'open': {'date': '2024-10-06', 'day': 0, 'time': '1000'}},
#     {'close': {'date': '2024-10-07', 'day': 1, 'time': '2030'},
#      'open': {'date': '2024-10-07', 'day': 1, 'time': '1100'}},
#     {'close': {'date': '2024-10-08', 'day': 2, 'time': '2030'},
#      'open': {'date': '2024-10-08', 'day': 2, 'time': '1100'}},
#     {'close': {'date': '2024-10-09', 'day': 3, 'time': '2030'},
#      'open': {'date': '2024-10-09', 'day': 3, 'time': '1100'}},
#     {'close': {'date': '2024-10-10', 'day': 4, 'time': '2030'},
#      'open': {'date': '2024-10-10', 'day': 4, 'time': '1100'}},
#     {'close': {'date': '2024-10-11', 'day': 5, 'time': '2100'},
#      'open': {'date': '2024-10-11', 'day': 5, 'time': '1100'}},
#     {'close': {'date': '2024-10-12', 'day': 6, 'time': '2100'},
#      'open': {'date': '2024-10-12', 'day': 6, 'time': '1000'}}],
#    'weekday_text': ['Monday: 11:00\u202fAM\u2009–\u20098:30\u202fPM',
#     'Tuesday: 11:00\u202fAM\u2009–\u20098:30\u202fPM',
#     'Wednesday: 11:00\u202fAM\u2009–\u20098:30\u202fPM',
#     'Thursday: 11:00\u202fAM\u2009–\u20098:30\u202fPM',
#     'Friday: 11:00\u202fAM\u2009–\u20099:00\u202fPM',
#     'Saturday: 10:00\u202fAM\u2009–\u20099:00\u202fPM',
#     'Sunday: 10:00\u202fAM\u2009–\u20098:30\u202fPM']},
#   'delivery': False,
#   'dine_in': True,
#   'editorial_summary': {'language': 'en',
#    'overview': 'Special-occasion Californian restaurant with a grand ambiance & sweeping views of the Pacific.'},
#   'formatted_address': '27400 Pacific Coast Hwy, Malibu, CA 90265, USA',
#   'formatted_phone_number': '(310) 457-1519',
#   'geometry': {'location': {'lat': 34.0253497, 'lng': -118.7698216},
#    'viewport': {'northeast': {'lat': 34.02668138029149,
#      'lng': -118.7683833197085},
#     'southwest': {'lat': 34.02398341970849, 'lng': -118.7710812802915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'international_phone_number': '+1 310-457-1519',
#   'name': "Geoffrey's",
#   'opening_hours': {'open_now': True,
#    'periods': [{'close': {'day': 0, 'time': '2030'},
#      'open': {'day': 0, 'time': '1000'}},
#     {'close': {'day': 1, 'time': '2030'}, 'open': {'day': 1, 'time': '1100'}},
#     {'close': {'day': 2, 'time': '2030'}, 'open': {'day': 2, 'time': '1100'}},
#     {'close': {'day': 3, 'time': '2030'}, 'open': {'day': 3, 'time': '1100'}},
#     {'close': {'day': 4, 'time': '2030'}, 'open': {'day': 4, 'time': '1100'}},
#     {'close': {'day': 5, 'time': '2100'}, 'open': {'day': 5, 'time': '1100'}},
#     {'close': {'day': 6, 'time': '2100'}, 'open': {'day': 6, 'time': '1000'}}],
#    'weekday_text': ['Monday: 11:00\u202fAM\u2009–\u20098:30\u202fPM',
#     'Tuesday: 11:00\u202fAM\u2009–\u20098:30\u202fPM',
#     'Wednesday: 11:00\u202fAM\u2009–\u20098:30\u202fPM',
#     'Thursday: 11:00\u202fAM\u2009–\u20098:30\u202fPM',
#     'Friday: 11:00\u202fAM\u2009–\u20099:00\u202fPM',
#     'Saturday: 10:00\u202fAM\u2009–\u20099:00\u202fPM',
#     'Sunday: 10:00\u202fAM\u2009–\u20098:30\u202fPM']},
#   'photos': [{'height': 2988,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112116470394197193987">Cindy Oh</a>'],
#     'photo_reference': 'AdCG2DMiiSzGwSlzJHjKksWO6tp-GD_7AkGE_RCsvZ27j8khS6fKuS-xt3hTAuQTs2YPlKXvAMAAFa-XkAv_jFoOlk5JFXuJ8UCug9jswl7c2NeQoIYVN6rhE1PXczBDAyHBtFmRadcX2jJoQ85lhvDqvLr0Q8DBQI4mok9Aa1qjsrpkcLlU',
#     'width': 3984},
#    {'height': 4000,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/118052613709563246496">Kari W.</a>'],
#     'photo_reference': 'AdCG2DOOzoEJfzZ5Mo6Kx0bSsl6RZnqvA8q1hZ5QxfQEyFHzAu_CVXenCh1sXA4Zh-FVa2rrui1pu6Mp1ycABXmS9SF-LxxPq_4OOa7oRhsyMcSvlxxKQQ1aivd7YG0ecT8LSF7XNgwIM_S-r916mo-hR0psctenWEcKHRoK-EC3vcIaUjIy',
#     'width': 3000},
#    {'height': 1868,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113253333277813310013">Jazzy U. (Jazzy)</a>'],
#     'photo_reference': 'AdCG2DPasmAF7bKIVJEoO6fshfkBRhYFDTxuRohMhX7LZ-QvIhPoKCPvbzMAj0MMVvAP9u4QZOXDlS8zM5Du8GwNaFH53PC8bagsaKwMFAQFf3rBB2GvTB9c5ND2xrU-Czbq1xnYP1njLrYT6uNX_h7nOUZFDPiSNKf0bQCSHW5tdy77mLCG',
#     'width': 4000},
#    {'height': 4000,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107152190076731796260">Peter Xaymountry</a>'],
#     'photo_reference': 'AdCG2DOb0TCwv_PcNBXmckHb4PtBnUBIIyZpx7XOLv_BPX825II9U7Ybt8rZkUZ9sB3hNSDztFZR6tdZyoDg-YdRB5MJxjKB-R4vsem3MHug6otU-zsr8MBToEK4cwoNVltS45wwwl6Oilar67uAurVkOYTnXc0ahza4O-vhl-96jHQSB5TY',
#     'width': 3000},
#    {'height': 4000,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107152190076731796260">Peter Xaymountry</a>'],
#     'photo_reference': 'AdCG2DNfaSY5Rw7rBSjFXkkiUN3AGpwzNaMS_ufturRZJ1DaoI6JNbPVxZiimK3znoOouEfBROjG2LTY_6Y08N3SwZYTCHEzAyfmFaE7xyf_RS5Iy15rDKtWo_uCgPXQwUoymqoAHoHwgHSYs5SFFQn2yHwYF6rlrRsMiiZXN_S6ybfrLBkn',
#     'width': 3000},
#    {'height': 3095,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105618547304220878516">Arjan de Raaf</a>'],
#     'photo_reference': 'AdCG2DPjofLjxpH52KXTf4OI0fiMMrRdUWs4-zHhf63z4U-TydDLF1ULR0t8Yx8QHA3QRYX6WjhF04IgKtsNSrHQogU1xqkFGah638ZCXReQf0BoZfC6DyjY2WXly3pX62_keqmdh1OlU8TOE1W0Aox4-Wq8WHVOEmOh5h-7zIdIp19KJ9U',
#     'width': 3024},
#    {'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110591305375079165153">Negar Omidvari</a>'],
#     'photo_reference': 'AdCG2DPYb4PUJtF2485YCc6H9UHVvH-O3qagfNUnf5sa3Ne7l2Lhh5yAqGsqnlhNXOP3Ez3TtL5yps6hk3CGDMRp2BBRh3GqSa3Z43VZfl8RtgV66j3VBsF9uV9SKrkGQ7VImi37jkCpolW7P2t4kMYH52-3KyYpJ4NwfnaeNZ8cVY_tCdNJ',
#     'width': 4032},
#    {'height': 3072,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106847320636162238488">vienna ilagan</a>'],
#     'photo_reference': 'AdCG2DOutUPNknX2Q_OQ_TsS70IFeDQaNwjUxtVmrjh7MgzgQDMrwOxnijb5xGJhIO4Z6e1fRWgy8fyIIvWHAd5S228c-2eAwXv_pICv5d1ciM4mmwTWNY4Wbmr4dcPt6dVxuBzbQPyMnjcn5WBOHtlErF7yamXsk8pnbXHaKMQXbCXPOJ4k',
#     'width': 4080},
#    {'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104433965895582639628">Marius CHIRITA</a>'],
#     'photo_reference': 'AdCG2DNFeDSSa6jr4DudrGTrAwCXouxyfSSoHIA7xtzdMjQWPIqUq3SUxicaalaIXBErc4ZPZFIgLGPJ0m7jjojx6hDeU-3agbnl4M8dFVYpg88OH8hDdtg1MlhQG3y5GLCxgpAxYNjQtYGiuZOZz8214viZTAhqgpgrpB4jQ8QgkjDe7X6l',
#     'width': 4032},
#    {'height': 3072,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106847320636162238488">vienna ilagan</a>'],
#     'photo_reference': 'AdCG2DP98r0yL3oo_QLHdL2P6Naas7msL7cOwSbqNok1ilDyX5WfpCGl5HpLCQy1cNMdnSED9LokHKSKtycJc0qh8hlV3Ajla9g5QhOltuL1DvBduPYLwuFtUGsPLhNCoMCGO8EWar5E7KpZG1UQ2B2OOxwv6wI1kRD41MJomFE7gv0aTkpD',
#     'width': 4080}],
#   'place_id': 'ChIJHRDtTtIY6IAR1xN4Fw2fiGA',
#   'plus_code': {'compound_code': '26GJ+43 Malibu, CA, USA',
#    'global_code': '856326GJ+43'},
#   'price_level': 3,
#   'rating': 4.3,
#   'reference': 'ChIJHRDtTtIY6IAR1xN4Fw2fiGA',
#   'reservable': True,
#   'reviews': [{'author_name': 'Peter Xaymountry',
#     'author_url': 'https://www.google.com/maps/contrib/107152190076731796260/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjW4-iw-e0tHl9zEINryHZo0RHkxSU2aUq1A5Ys5v7J6GgxmO6ZN=s128-c0x00000000-cc-rp-mo-ba7',
#     'rating': 4,
#     'relative_time_description': '3 weeks ago',
#     'text': "You come here for the view of the beach which is the main attraction especially if you get a good seat. I decided to take my wife here for her birthday so I made reservations ahead of time off OpenTable and told them we were celebrating a birthday so I wanted a table with good view of the water. We arrived early and use their valet parking because it's easier than finding street parking. The valet cost is already added to your bill so you don't have to worry about cash except for tip. We arrived early so we took advantage on walking down to the beach first. We checked in like 20 minutes before our reservation time but they were still able to seat us with a great table with good view of the water. Our waiter was Marvin and we thought he was great with us beside not telling me that the soda is not free refill. That was my only complaint with him but I didn't want to dispute so I just paid it but give less in the tip. My wife got the Pan Seared Chilean Sea Bass for her entree and a Georgia Peach martini for her drink. I got their Herb Crusted Salmon and ask for french fries for my sides. My wife loved her peach martini and of course her Sea Bass. I thought the Salmon was a bit dry and didn't have much favor but Marvin came around asking if I wanted crushed black pepper so I asked for that on the Salmon and fries. It helped a little but not that much to me. We finish off the night with a ice cream dessert where Marvin sang Happy Birthday to my wife. I would recommend coming here and making reservations if you want to experience a good view and some good food but just know that the soda does not have free refills.",
#     'time': 1725852601,
#     'translated': False},
#    {'author_name': 'Carman Carter',
#     'author_url': 'https://www.google.com/maps/contrib/101520279057737812167/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a/ACg8ocIKKaN7Ul4FlHA_qDnQcSiu3zwUyig_utY7Z6wwzAx7LOPN_g=s128-c0x00000000-cc-rp-mo-ba5',
#     'rating': 5,
#     'relative_time_description': 'a month ago',
#     'text': 'Geoffrey’s never disappoints! Been going here since 2001 and this place has not changed much.  Last time here was about 10 years ago.  Still same great service, food, and atmosphere!  Keep in mind if you choose to park on your own, good luck!  Highly recommend either car service or valet. The valet crew is so awesome and as always takes care of everyone with a smile! They were great with our driver. Super polite and accommodating when he dropped us off and picked us up.\nWe love to sit at the bar.  If you do this make sure you sit on the far side so you can see the ocean.  Our bartender was great!  Lots of personality and really enjoyed our time there.\nThe food as always was excellent! We went on a Sunday.  Sat and Sunday they have a great brunch menu.',
#     'time': 1725282499,
#     'translated': False},
#    {'author_name': 'Liz',
#     'author_url': 'https://www.google.com/maps/contrib/116886163617925008970/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjWZnS6QCoPLAi5H79CbNHBMAV0GrOm9UB5RNwt_TKpI54Ldm2pejw=s128-c0x00000000-cc-rp-mo-ba5',
#     'rating': 5,
#     'relative_time_description': 'in the last week',
#     'text': 'First time at this lovely restaurant.  Views and ambience are amazing, they only have valet parking which was $12 not including tip. The service was impeccable, they also did not rush the food service it was at a nice pace. Lovely presentation and food was delicious,  would not hesitate to go back. We were celebrating birthdays.',
#     'time': 1727806644,
#     'translated': False},
#    {'author_name': 'Jennifer Villasenor',
#     'author_url': 'https://www.google.com/maps/contrib/113372860495121882697/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjXxBi2C7_XnjfulHXrIAt7jvpfgGg8XYxJgucH70R6vKX4nUGlDJg=s128-c0x00000000-cc-rp-mo',
#     'rating': 4,
#     'relative_time_description': '3 weeks ago',
#     'text': 'Lovely view, ambiance, and service. I didn’t give it 5 stars because it was good but not amazing. I think the location is the biggest take away. Definitely pricey but not surprising. The waiters were really cool. Parking situation can def get crazy during peak hours . Seems very family oriented which is nice.',
#     'time': 1726352784,
#     'translated': False},
#    {'author_name': 'Shant Khach',
#     'author_url': 'https://www.google.com/maps/contrib/109352422604154094065/reviews',
#     'language': 'en',
#     'original_language': 'en',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjWm6TJxGt0joahs8kCc6OXUwy3J4tj4XGHfrZtpML1JX1iRXBo=s128-c0x00000000-cc-rp-mo-ba4',
#     'rating': 5,
#     'relative_time_description': 'a month ago',
#     'text': 'Great place with a nice view of the ocean.  They have valet parking and access to the ocean by walking the stairs down. Service is great and good was good too. We enjoyed our time there with our family and kids got happy by playing on the beach after our meal.',
#     'time': 1725297497,
#     'translated': False}],
#   'serves_beer': True,
#   'serves_breakfast': True,
#   'serves_brunch': True,
#   'serves_dinner': True,
#   'serves_lunch': True,
#   'serves_vegetarian_food': True,
#   'serves_wine': True,
#   'takeout': True,
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'url': 'https://maps.google.com/?cid=6955984503050867671',
#   'user_ratings_total': 2442,
#   'utc_offset': -420,
#   'vicinity': '27400 Pacific Coast Highway, Malibu',
#   'website': 'http://geoffreysmalibu.com/',
#   'wheelchair_accessible_entrance': True},
#  'status': 'OK'}
